# %%
import numpy as np
from pymoo.core.problem import ElementwiseProblem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PM
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.optimize import minimize

# %%
class MyProblem(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var=1,
                         n_obj=1,
                         
                         xl=-10,
                         xu=10)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = (x-3)**2

        out["F"] = [f1]
       


problem = MyProblem()

algorithm = NSGA2(
    pop_size=40,
    n_offsprings=10,
    eliminate_duplicates=True,
    save_history=True
)

# %%
res = minimize(problem,
               algorithm,
               
               seed=1,
               save_history=True,
               verbose=True)

X = res.X
F = res.F
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |       40 |      1 |             - |             -
#      2 |       50 |      1 |  0.000000E+00 |             f
#      3 |       60 |      1 |  0.000000E+00 |             f
#      4 |       70 |      1 |  0.000000E+00 |             f
#      5 |       80 |      1 |  0.000000E+00 |             f
#      6 |       90 |      1 |  0.000000E+00 |             f
#      7 |      100 |      1 |  0.0920397685 |         ideal
#      8 |      110 |      1 |  0.1674380828 |         ideal
#      9 |      120 |      1 |  0.000000E+00 |             f
#     10 |      130 |      1 |  0.0177798470 |         ideal
#     11 |      140 |      1 |  0.000000E+00 |             f
#     12 |      150 |      1 |  0.0026803624 |         ideal
#     13 |      160 |      1 |  0.000000E+00 |             f
#     14 |      170 |      1 |  0.000000E+00 |             f
#     15 |      180 |      1 |  0.0011398339 |             f
#     16 |      190 |      1 |  0.0011398339 |             f
#     17 |      200 |      1 |  0.0011398339 |             f
#     18 |      210 |      1 |  0.0011398339 |             f
#     19 |      220 |      1 |  0.0011791634 |             f
#     20 |      230 |      1 |  0.0011791634 |             f
#     21 |      240 |      1 |  0.0011791634 |             f
#     22 |      250 |      1 |  0.0011791634 |             f
#     23 |      260 |      1 |  0.0011791634 |             f
#     24 |      270 |      1 |  0.0011791634 |             f
#     25 |      280 |      1 |  0.0011791634 |             f
#     26 |      290 |      1 |  0.0011791634 |             f
#     27 |      300 |      1 |  0.0011791634 |             f
#     28 |      310 |      1 |  0.0011791634 |             f
#     29 |      320 |      1 |  0.0011791634 |             f
#     30 |      330 |      1 |  0.0011791634 |             f
#     31 |      340 |      1 |  0.0011791634 |             f
#     32 |      350 |      1 |  0.0011791634 |             f
#     33 |      360 |      1 |  0.0011791634 |             f
#     34 |      370 |      1 |  0.0011791634 |             f
#     35 |      380 |      1 |  0.0011791634 |             f
#     36 |      390 |      1 |  0.0011791634 |             f
#     37 |      400 |      1 |  0.0011791634 |             f
#     38 |      410 |      1 |  0.0011791634 |             f
#     39 |      420 |      1 |  0.0011791636 |             f
#     40 |      430 |      1 |  0.0011791636 |             f
#     41 |      440 |      1 |  0.0011791636 |             f
#     42 |      450 |      1 |  0.0011791636 |             f
#     43 |      460 |      1 |  0.0011791636 |             f
#     44 |      470 |      1 |  0.0011791636 |             f
#     45 |      480 |      1 |  0.0011791636 |             f
#     46 |      490 |      1 |  0.0011791636 |             f
#     47 |      500 |      1 |  0.0011791636 |             f
#     48 |      510 |      1 |  0.0011791639 |             f
#     49 |      520 |      1 |  0.0011791639 |             f
#     50 |      530 |      1 |  0.0011791639 |             f
#     51 |      540 |      1 |  0.0011791639 |             f
#     52 |      550 |      1 |  0.0011791639 |             f
#     53 |      560 |      1 |  0.0011791639 |             f
#     54 |      570 |      1 |  0.0011791639 |             f
#     55 |      580 |      1 |  0.0011791639 |             f
#     56 |      590 |      1 |  0.0011791639 |             f
#     57 |      600 |      1 |  0.0011791639 |             f
#     58 |      610 |      1 |  0.0011791639 |             f
#     59 |      620 |      1 |  0.0011791639 |             f
#     60 |      630 |      1 |  0.0011791639 |             f
#     61 |      640 |      1 |  0.0011791639 |             f
#     62 |      650 |      1 |  0.0011791639 |             f

# %%
print(res.X)
print(res.F)
# Out:
# [2.99999237]
# [5.8257343e-11]
