# %%
import numpy as np
from pymoo.core.problem import ElementwiseProblem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PM
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.optimize import minimize
import matplotlib.pyplot as plt

# %% [markdown]
# ## EQ = 1

# %%
class MyProblem(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var=2,
                         n_obj=2,
                         n_eq_constr=1,
                         xl=np.array([-5,-5]),
                         xu=np.array([5,5]))

    def _evaluate(self, X, out, *args, **kwargs):

        x = X[0]
        y = X[1]
        
        f1 = x**2 + y**2
        f2 = (x-1)**2 + (y-1)**2
        out["F"] = [f1,f2]

        g1 = x+y-1
        out["H"] = [g1]


problem = MyProblem()

algorithm = NSGA2(
    n_max_gen = 100,
    pop_size=10,
    eliminate_duplicates=True,
    save_history=True
)

# %%
res = minimize(problem,
               algorithm,
               
               seed=1,
               save_history=True,
               verbose=True)

X = res.X
F = res.F
# Out:
# ==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |       40 |      1 |  0.0718094014 |  3.6083665236 |             - |             -
#      2 |       50 |      1 |  0.0718094014 |  2.5846610943 |             - |             -
#      3 |       60 |      1 |  0.0718094014 |  2.2597131492 |             - |             -
#      4 |       70 |      1 |  0.0718094014 |  1.9087616347 |             - |             -
#      5 |       80 |      1 |  0.0279503877 |  1.5020397093 |             - |             -
#      6 |       90 |      1 |  0.0070146771 |  1.2065294833 |             - |             -
#      7 |      100 |      1 |  0.0070146771 |  0.9881035378 |             - |             -
#      8 |      110 |      1 |  0.0070146771 |  0.7486267625 |             - |             -
#      9 |      120 |      1 |  0.0070146771 |  0.6903465397 |             - |             -
#     10 |      130 |      1 |  0.0070146771 |  0.5701781845 |             - |             -
#     11 |      140 |      1 |  0.0070146771 |  0.4763654575 |             - |             -
#     12 |      150 |      1 |  0.0070146771 |  0.3411486399 |             - |             -
#     13 |      160 |      1 |  0.0017410386 |  0.2614780319 |             - |             -
#     14 |      170 |      1 |  0.0017410386 |  0.2203774646 |             - |             -
#     15 |      180 |      1 |  0.0014352801 |  0.1645031115 |             - |             -
#     16 |      190 |      1 |  0.0014352801 |  0.1274668233 |             - |             -
#     17 |      200 |      1 |  0.0014352801 |  0.1056468499 |             - |             -
#     18 |      210 |      1 |  0.0014352801 |  0.1025959799 |             - |             -
#     19 |      220 |      1 |  0.0014352801 |  0.0792673665 |             - |             -
#     20 |      230 |      1 |  0.0001522678 |  0.0706734057 |             - |             -
#     21 |      240 |      1 |  0.0001522678 |  0.0604353585 |             - |             -
#     22 |      250 |      1 |  0.0001522678 |  0.0538107986 |             - |             -
#     23 |      260 |      1 |  0.0001522678 |  0.0441313980 |             - |             -
#     24 |      270 |      1 |  0.0001522678 |  0.0436434643 |             - |             -
#     25 |      280 |      1 |  0.0001522678 |  0.0429541556 |             - |             -
#     26 |      290 |      1 |  0.0001522678 |  0.0429541556 |             - |             -
#     27 |      300 |      1 |  0.0001522678 |  0.0409002992 |             - |             -
#     28 |      310 |      1 |  0.0001522678 |  0.0395381566 |             - |             -
#     29 |      320 |      1 |  0.0001522678 |  0.0387928097 |             - |             -
#     30 |      330 |      1 |  0.0001522678 |  0.0352554903 |             - |             -
#     31 |      340 |      1 |  0.0001522678 |  0.0327652044 |             - |             -
#     32 |      350 |      1 |  0.0001522678 |  0.0299782582 |             - |             -
#     33 |      360 |      1 |  0.0001522678 |  0.0280100779 |             - |             -
#     34 |      370 |      1 |  0.0001522678 |  0.0279846324 |             - |             -
#     35 |      380 |      1 |  0.0001522678 |  0.0255314358 |             - |             -
#     36 |      390 |      1 |  0.0001522678 |  0.0253012215 |             - |             -
#     37 |      400 |      1 |  0.0001522678 |  0.0222761589 |             - |             -
#     38 |      410 |      1 |  0.0001522678 |  0.0219395645 |             - |             -
#     39 |      420 |      1 |  0.0001522678 |  0.0198078404 |             - |             -
#     40 |      430 |      1 |  0.0001522678 |  0.0194354986 |             - |             -
#     41 |      440 |      1 |  0.0001522678 |  0.0183088718 |             - |             -
#     42 |      450 |      1 |  0.0001522678 |  0.0157378153 |             - |             -
#     43 |      460 |      1 |  0.0001522678 |  0.0146764286 |             - |             -
#     44 |      470 |      1 |  0.0001522678 |  0.0145089792 |             - |             -
#     45 |      480 |      1 |  0.0001522678 |  0.0131649414 |             - |             -
#     46 |      490 |      1 |  0.0001522678 |  0.0131649414 |             - |             -
#     47 |      500 |      1 |  0.0001522678 |  0.0131649414 |             - |             -
#     48 |      510 |      1 |  0.0001522678 |  0.0128233147 |             - |             -
#     49 |      520 |      1 |  0.0001522678 |  0.0115805069 |             - |             -
#     50 |      530 |      1 |  0.0001522678 |  0.0112922716 |             - |             -
#     51 |      540 |      1 |  0.0001522678 |  0.0110201927 |             - |             -
#     52 |      550 |      1 |  0.0001522678 |  0.0100047657 |             - |             -
#     53 |      560 |      1 |  0.0001522678 |  0.0096952573 |             - |             -
#     54 |      570 |      1 |  0.0001522678 |  0.0096952573 |             - |             -
#     55 |      580 |      1 |  0.0001522678 |  0.0089866804 |             - |             -
#     56 |      590 |      1 |  0.0001522678 |  0.0079856361 |             - |             -
#     57 |      600 |      1 |  0.0001522678 |  0.0076329091 |             - |             -
#     58 |      610 |      1 |  0.0001522678 |  0.0074039867 |             - |             -
#     59 |      620 |      1 |  0.0001522678 |  0.0071345260 |             - |             -
#     60 |      630 |      1 |  0.0001522678 |  0.0068131125 |             - |             -
#     61 |      640 |      1 |  0.0001522678 |  0.0064580877 |             - |             -
#     62 |      650 |      1 |  0.0001522678 |  0.0064580877 |             - |             -
#     63 |      660 |      1 |  0.0001522678 |  0.0061722986 |             - |             -
#     64 |      670 |      1 |  0.0001522678 |  0.0061722986 |             - |             -
#     65 |      680 |      1 |  0.0001522678 |  0.0061722986 |             - |             -
#     66 |      690 |      1 |  0.0001522678 |  0.0058858304 |             - |             -
#     67 |      700 |      1 |  0.0001522678 |  0.0058754367 |             - |             -
#     68 |      710 |      1 |  0.0001522678 |  0.0055321421 |             - |             -

# %%
res.pop.get("F")[:,0]
# Out:
# array([16.04504502, 16.04428378, 12.91724839, 26.03726583, 12.91909584,
#        16.05599163, 16.05680249, 36.72577116, 16.05831339, 16.05881424,
#        16.06760965, 16.06756438, 15.93662903, 12.89799662, 12.89792363,
#        16.24129896, 16.06660594, 16.06589258, 16.0345724 , 16.44549789,
#        14.8257602 , 16.43667654, 14.81953379, 16.43475464, 13.55969102,
#        14.83239773, 14.83268378, 14.83270042, 14.9243911 , 16.43292151,
#        12.90948327, 14.92076653, 15.97794997, 15.97761596, 15.97471099,
#        15.99273734, 16.34992059, 14.52520157, 14.33555648, 16.34400998])

# %%
print(res.X)
print(res.F)
# Out:
# None
# None

# %%
obj1 = res.pop.get("F")[:,0]
obj2= res.pop.get("F")[:,1]
vars = res.pop.get("X")
plt.scatter(obj1,obj2)
plt.scatter(vars[:,0],vars[:,1])

# %% [markdown]
# ## Grafico EQ = 1

# %%
obj1 = res.pop.get("F")[:,0]
obj2= res.pop.get("F")[:,1]
vars = res.pop.get("X")
plt.scatter(obj1,obj2)
plt.scatter(vars[:,0],vars[:,1])
