# %%
import os
from brapi import Brapi
from dotenv import load_dotenv
import pandas as pd
import requests
import json

from pathlib import Path

# %%
api_k = 'qyWJMQp7dX6TcaKH88xyiM'

# %%
client = Brapi(
    api_key=api_k,
    environment="production",  # 'production' ou 'sandbox'
    max_retries=2,  # Número de tentativas (padrão: 2)
    timeout=60.0,  # Timeout em segundos (padrão: 60)
)

# %%
lista_ativos = [
"ALOS3",
"ABEV3",
"ANIM3",
"ASAI3",
"AURE3",
"AXIA3",
"AZZA3",
"B3SA3",
"BBSE3",
"BBDC3",
"BBDC4",
"BRAP4",
"SAUD3",
"BBAS3",
"BRKM5",
"BRAV3",
"BPAC11",
"CXSE3",
"CBAV3",
"CEAB3",
"CMIG4",
"COGN3",
"CSMG3",
"CPLE3",
"CSAN3",
"CPFE3",
"CMIN3",
"CURY3",
"CVCB3",
"CYRE3",
"DIRR3",
"ECOR3",
"EMBJ3",
"ENGI11",
"ENEV3",
"EGIE3",
"EQTL3",
"EZTC3",
"FLRY3",
"GGBR4",
"GOAU4",
"GGPS3",
"GMAT3",
"HAPV3",
"HYPE3",
"IGTI11",
"INTB3",
"IRBR3",
"ISAE4",
"ITSA4",
"ITUB3",
"ITUB4",
"JHSF3",
"KLBN11",
"RENT3",
"LREN3",
"MGLU3",
"POMO4",
"MBRF3",
"BEEF3",
"MOTV3",
"MDNE3",
"MOVI3",
"MRVE3",
"MULT3",
"NATU3",
"ORVR3",
"PETR3",
"PETR4",
"RECV3",
"AUAU3",
"PSSA3",
"PRIO3",
"RADL3",
"RAPT4",
"RDOR3",
"RAIL3",
"SBSP3",
"SAPR11",
"SANB11",
"SMTO3",
"CSNA3",
"SIMH3",
"SLCE3",
"SMFT3",
"SUZB3",
"TAEE11",
"VIVT3",
"TEND3",
"TIMS3",
"TOTS3",
"UGPA3",
"USIM5",
"VALE3",
"VAMO3",
"VBBR3",
"VIVA3",
"WEGE3",
"YDUQ3",
]
print(f"Tamanho da Lista de ativos IBRX: {len(lista_ativos)}")
# lista_ativos = []
# for item in lista_ativos1:
#     lista_ativos.append(item[:-3])
# Out:
# Tamanho da Lista de ativos IBRX: 99

# %%
dataframe_collection = []
ativos_problema = []

for stock in lista_ativos:
    # ticker = stock.stock
    try:    
        ticker = stock

        dataframe_stock = []

        url = f"https://brapi.dev/api/v2/stocks/income-statement?symbols={ticker}"
        print(url)
        response = requests.request("GET", url, headers = {
        "Authorization": api_k
        })

        
            
        

        info_final = {
            'ativo':stock,
            'data':pd.DataFrame(response.json()['results'][0]['data']).set_index('endDate')
        }
        dataframe_stock.append(info_final)

        dataframe_collection.append(dataframe_stock)
    except Exception as e:
        print("Ticker com problema: ",ticker)
        ativos_problema.append(ticker)

        continue
# Out:
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ALOS3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ABEV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ANIM3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ASAI3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=AURE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=AXIA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=AZZA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=B3SA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BBSE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BBDC3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BBDC4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BRAP4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SAUD3
# Ticker com problema:  SAUD3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BBAS3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BRKM5
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BRAV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BPAC11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CXSE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CBAV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CEAB3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CMIG4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=COGN3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CSMG3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CPLE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CSAN3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CPFE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CMIN3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CURY3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CVCB3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CYRE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=DIRR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ECOR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=EMBJ3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ENGI11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ENEV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=EGIE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=EQTL3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=EZTC3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=FLRY3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=GGBR4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=GOAU4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=GGPS3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=GMAT3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=HAPV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=HYPE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=IGTI11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=INTB3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=IRBR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ISAE4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ITSA4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ITUB3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ITUB4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=JHSF3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=KLBN11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=RENT3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=LREN3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MGLU3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=POMO4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MBRF3
# Ticker com problema:  MBRF3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=BEEF3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MOTV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MDNE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MOVI3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MRVE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=MULT3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=NATU3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=ORVR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=PETR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=PETR4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=RECV3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=AUAU3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=PSSA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=PRIO3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=RADL3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=RAPT4
# https://brapi.dev/api/v2/stocks/income-statement?symbols=RDOR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=RAIL3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SBSP3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SAPR11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SANB11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SMTO3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=CSNA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SIMH3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SLCE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SMFT3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=SUZB3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=TAEE11
# https://brapi.dev/api/v2/stocks/income-statement?symbols=VIVT3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=TEND3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=TIMS3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=TOTS3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=UGPA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=USIM5
# https://brapi.dev/api/v2/stocks/income-statement?symbols=VALE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=VAMO3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=VBBR3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=VIVA3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=WEGE3
# https://brapi.dev/api/v2/stocks/income-statement?symbols=YDUQ3

# %%
for ativo in dataframe_collection:
    nome_ativo = ativo[0]['ativo']
    df = ativo[0]['data']
    df.to_csv('dre/'+nome_ativo)

# %%
lista_df = []

for filename in os.listdir('dre'):
    
    # 2. Reconstruct the full absolute or relative path to the file
    full_path = os.path.join('dre', filename)
    
    # 3. Check if the current item is actually a file (and not a subfolder)
    # if os.path.isfile(full_path):
        
    #     # 4. Open and process the file safely
    #     with open(full_path, "r", encoding="utf-8") as file:
    #         content = file.read()
    #         print(f"--- Content of {filename} ---")
    #         print(pd.read_csv(full_path))
    dicio = {
        'ativo':filename,
        'data':pd.read_csv(full_path)
    }

    lista_df.append(dicio)

# %%
print(lista_df[0]['ativo'])
print(lista_df[0]['data'].columns.tolist())
# Out:
# ABEV3
# ['endDate', 'type', 'totalRevenue', 'costOfRevenue', 'grossProfit', 'researchDevelopment', 'sellingGeneralAdministrative', 'nonRecurring', 'otherOperatingExpenses', 'totalOperatingExpenses', 'operatingIncome', 'totalOtherIncomeExpenseNet', 'ebit', 'interestExpense', 'incomeBeforeTax', 'incomeTaxExpense', 'minorityInterest', 'netIncomeFromContinuingOps', 'discontinuedOperations', 'extraordinaryItems', 'effectOfAccountingCharges', 'otherItems', 'netIncome', 'netIncomeApplicableToCommonShares', 'salesExpenses', 'lossesDueToNonRecoverabilityOfAssets', 'otherOperatingIncome', 'equityIncomeResult', 'financialResult', 'financialIncome', 'financialExpenses', 'currentTaxes', 'deferredTaxes', 'incomeBeforeStatutoryParticipationsAndContributions', 'basicEarningsPerCommonShare', 'dilutedEarningsPerCommonShare', 'basicEarningsPerPreferredShare', 'profitSharingAndStatutoryContributions', 'dilutedEarningsPerPreferredShare', 'claimsAndOperationsCosts', 'administrativeCosts', 'otherOperatingIncomeAndExpenses', 'earningsPerShare', 'basicEarningsPerShare', 'dilutedEarningsPerShare', 'insuranceOperations', 'reinsuranceOperations', 'complementaryPensionOperations', 'capitalizationOperations', 'cleanEbit', 'cleanEbitda', 'cleanNopat', 'cleanNetIncome']

# %%
lista_df[0]['data'][['endDate','type','totalRevenue']]
# Out:
#        endDate    type  totalRevenue
# 0   2025-12-31  yearly   88242470000
# 1   2024-12-31  yearly   89452670000
# 2   2023-12-31  yearly   79736860000
# 3   2022-12-31  yearly   79708820000
# 4   2021-12-31  yearly   72854350000
# 5   2020-12-31  yearly   58378994000
# 6   2019-12-31  yearly   52599710000
# 7   2018-12-31  yearly   50231337000
# 8   2017-12-31  yearly   47899275000
# 9   2016-12-31  yearly   45602562000
# 10  2015-12-31  yearly   46720140000
# 11  2014-12-31  yearly   38079787000
# 12  2013-12-31  yearly   34791390000
# 13  2012-12-31  yearly             0
