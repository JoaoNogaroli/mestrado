# %%
import os
from brapi import Brapi
from dotenv import load_dotenv
import pandas as pd
import requests

# %%
api_k = 'qyWJMQp7dX6TcaKH88xyiM'

# %%
client = Brapi(
    api_key=api_k,
    environment="production",  # 'production' ou 'sandbox'
    max_retries=2,  # Número de tentativas (padrão: 2)
    timeout=60.0,  # Timeout em segundos (padrão: 60)
)

# %%
lista_ativos = [
"ALOS3",
"ABEV3",
"ANIM3",
"ASAI3",
"AURE3",
"AXIA3",
"AZZA3",
"B3SA3",
"BBSE3",
"BBDC3",
"BBDC4",
"BRAP4",
"SAUD3",
"BBAS3",
"BRKM5",
"BRAV3",
"BPAC11",
"CXSE3",
"CBAV3",
"CEAB3",
"CMIG4",
"COGN3",
"CSMG3",
"CPLE3",
"CSAN3",
"CPFE3",
"CMIN3",
"CURY3",
"CVCB3",
"CYRE3",
"DIRR3",
"ECOR3",
"EMBJ3",
"ENGI11",
"ENEV3",
"EGIE3",
"EQTL3",
"EZTC3",
"FLRY3",
"GGBR4",
"GOAU4",
"GGPS3",
"GMAT3",
"HAPV3",
"HYPE3",
"IGTI11",
"INTB3",
"IRBR3",
"ISAE4",
"ITSA4",
"ITUB3",
"ITUB4",
"JHSF3",
"KLBN11",
"RENT3",
"LREN3",
"MGLU3",
"POMO4",
"MBRF3",
"BEEF3",
"MOTV3",
"MDNE3",
"MOVI3",
"MRVE3",
"MULT3",
"NATU3",
"ORVR3",
"PETR3",
"PETR4",
"RECV3",
"AUAU3",
"PSSA3",
"PRIO3",
"RADL3",
"RAPT4",
"RDOR3",
"RAIL3",
"SBSP3",
"SAPR11",
"SANB11",
"SMTO3",
"CSNA3",
"SIMH3",
"SLCE3",
"SMFT3",
"SUZB3",
"TAEE11",
"VIVT3",
"TEND3",
"TIMS3",
"TOTS3",
"UGPA3",
"USIM5",
"VALE3",
"VAMO3",
"VBBR3",
"VIVA3",
"WEGE3",
"YDUQ3",
]
print(f"Tamanho da Lista de ativos IBRX: {len(lista_ativos)}")
# lista_ativos = []
# for item in lista_ativos1:
#     lista_ativos.append(item[:-3])
# Out:
# Tamanho da Lista de ativos IBRX: 99

# %%
dataframe_collection = []
ativos_problemas = []
for stock in lista_ativos:
    # ticker = stock.stock
    try:    
        ticker = stock

        dataframe_stock = []

        url = f"https://brapi.dev/api/v2/stocks/balance-sheet?symbols={ticker}"
        print(url)
        response = requests.request("GET", url, headers = {
        "Authorization": api_k
        })

        
            
        

        info_final = {
            'ativo':stock,
            'data':pd.DataFrame(response.json()['results'][0]['data']).set_index('endDate')
        }
        dataframe_stock.append(info_final)

        dataframe_collection.append(dataframe_stock)
    except Exception as e:
        print("Ticker com problema: ",ticker)
        ativos_problemas.append(ticker)
        continue
# Out:
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ALOS3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ABEV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ANIM3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ASAI3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=AURE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=AXIA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=AZZA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=B3SA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BBSE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BBDC3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BBDC4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BRAP4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SAUD3
# Ticker com problema:  SAUD3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BBAS3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BRKM5
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BRAV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BPAC11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CXSE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CBAV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CEAB3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CMIG4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=COGN3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CSMG3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CPLE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CSAN3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CPFE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CMIN3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CURY3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CVCB3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CYRE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=DIRR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ECOR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=EMBJ3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ENGI11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ENEV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=EGIE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=EQTL3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=EZTC3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=FLRY3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=GGBR4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=GOAU4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=GGPS3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=GMAT3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=HAPV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=HYPE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=IGTI11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=INTB3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=IRBR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ISAE4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ITSA4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ITUB3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ITUB4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=JHSF3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=KLBN11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=RENT3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=LREN3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MGLU3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=POMO4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MBRF3
# Ticker com problema:  MBRF3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=BEEF3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MOTV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MDNE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MOVI3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MRVE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=MULT3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=NATU3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=ORVR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=PETR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=PETR4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=RECV3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=AUAU3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=PSSA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=PRIO3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=RADL3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=RAPT4
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=RDOR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=RAIL3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SBSP3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SAPR11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SANB11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SMTO3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=CSNA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SIMH3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SLCE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SMFT3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=SUZB3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=TAEE11
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=VIVT3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=TEND3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=TIMS3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=TOTS3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=UGPA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=USIM5
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=VALE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=VAMO3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=VBBR3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=VIVA3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=WEGE3
# https://brapi.dev/api/v2/stocks/balance-sheet?symbols=YDUQ3

# %%
len(dataframe_collection)
# Out:
# 97

# %%
import json

# %%
dataframe_collection[0][0]
# Out:
# {'ativo': 'ALOS3',
#  'data':               type       cash  shortTermInvestments  netReceivables  \
#  endDate
#  2025-12-31  yearly   60570000            2369444000       473703000
#  2024-12-31  yearly   47771000            3321334000       492790020
#  2023-12-31  yearly   44317000            2088913000       647058000
#  2022-12-31  yearly   18256000            2543865000       323223000
#  2021-12-31  yearly   14862000            1231460000       400545000
#  2020-12-31  yearly   13113000            1371587000       327539000
#  2019-12-31  yearly   32682000            1167366000       168992000
#  2018-12-31  yearly  280145000                     0        50694000
#  2017-12-31  yearly  448429000                     0        46883000
#  2016-12-31  yearly  256046000                     0        43755000
#  2015-12-31  yearly  265144990                     0        40398000
#  2014-12-31  yearly  315936000                     0        48666000
#  2013-12-31  yearly  424431000                     0        40196000
#  2012-12-31  yearly  681976000                     0        33605000
#  2011-12-31  yearly  390918020                     0        24690000
#  2010-12-31  yearly   61566000                     0        21833000
#
#              inventory  otherCurrentAssets  totalCurrentAssets  \
#  endDate
#  2025-12-31          0           226646000          3316531000
#  2024-12-31          0           244456000          4271851000
#  2023-12-31          0           895742000          3824320000
#  2022-12-31          0           333764000          3265974000
#  2021-12-31          0            74429000          1775374000
#  2020-12-31          0            80038000          1850926000
#  2019-12-31          0           119409000          1543252000
#  2018-12-31          0             4119000           344869000
#  2017-12-31          0             6669000           509367000
#  2016-12-31          0             7691000           312112000
#  2015-12-31          0            20116000           340059000
#  2014-12-31          0            22131000           397844000
#  2013-12-31          0             6954000           481589000
#  2012-12-31          0             4689000           736779000
#  2011-12-31          0             4971000           437849000
#  2010-12-31          0             5801000            99034000
#
#              longTermInvestments  propertyPlantEquipment otherAssets  ...  \
#  endDate                                                              ...
#  2025-12-31          20985772000               106620000        None  ...
#  2024-12-31          21325068000                97391000        None  ...
#  2023-12-31          22356287000                86970000        None  ...
#  2022-12-31           8220045000                20031000        None  ...
#  2021-12-31           8741747000                24495000        None  ...
#  2020-12-31           8526585000                26540000        None  ...
#  2019-12-31           8851493000                10381000        None  ...
#  2018-12-31           5018747000                 3205000        None  ...
#  2017-12-31           4687242000                 3315000        None  ...
#  2016-12-31           4535960000                 2872000        None  ...
#  2015-12-31           4448219000                 3403000        None  ...
#  2014-12-31           4244983000                 3357000        None  ...
#  2013-12-31           3979546000                 3163000        None  ...
#  2012-12-31           3276625000                 3495000        None  ...
#  2011-12-31           2802207000                 5972000        None  ...
#  2010-12-31           2200445000                 4532000        None  ...
#
#              longTermDebitsFromOperations longTermTechnicalProvisions  \
#  endDate
#  2025-12-31                          None                        None
#  2024-12-31                          None                        None
#  2023-12-31                          None                        None
#  2022-12-31                          None                        None
#  2021-12-31                          None                        None
#  2020-12-31                          None                        None
#  2019-12-31                          None                        None
#  2018-12-31                          None                        None
#  2017-12-31                          None                        None
#  2016-12-31                          None                        None
#  2015-12-31                          None                        None
#  2014-12-31                          None                        None
#  2013-12-31                          None                        None
#  2012-12-31                          None                        None
#  2011-12-31                          None                        None
#  2010-12-31                          None                        None
#
#             longTermInsuranceAndReinsurance longTermComplementaryPension  \
#  endDate
#  2025-12-31                            None                         None
#  2024-12-31                            None                         None
#  2023-12-31                            None                         None
#  2022-12-31                            None                         None
#  2021-12-31                            None                         None
#  2020-12-31                            None                         None
#  2019-12-31                            None                         None
#  2018-12-31                            None                         None
#  2017-12-31                            None                         None
#  2016-12-31                            None                         None
#  2015-12-31                            None                         None
#  2014-12-31                            None                         None
#  2013-12-31                            None                         None
#  2012-12-31                            None                         None
#  2011-12-31                            None                         None
#  2010-12-31                            None                         None
#
#             longTermCapitalization otherLongTermProvisions  \
#  endDate
#  2025-12-31                   None                    None
#  2024-12-31                   None                    None
#  2023-12-31                   None                    None
#  2022-12-31                   None                    None
#  2021-12-31                   None                    None
#  2020-12-31                   None                    None
#  2019-12-31                   None                    None
#  2018-12-31                   None                    None
#  2017-12-31                   None                    None
#  2016-12-31                   None                    None
#  2015-12-31                   None                    None
#  2014-12-31                   None                    None
#  2013-12-31                   None                    None
#  2012-12-31                   None                    None
#  2011-12-31                   None                    None
#  2010-12-31                   None                    None
#
#             debitsFromCapitalization  debitsFromOtherOperations  \
#  endDate
#  2025-12-31                     None                       None
#  2024-12-31                     None                       None
#  2023-12-31                     None                       None
#  2022-12-31                     None                       None
#  2021-12-31                     None                       None
#  2020-12-31                     None                       None
#  2019-12-31                     None                       None
#  2018-12-31                     None                       None
#  2017-12-31                     None                       None
#  2016-12-31                     None                       None
#  2015-12-31                     None                       None
#  2014-12-31                     None                       None
#  2013-12-31                     None                       None
#  2012-12-31                     None                       None
#  2011-12-31                     None                       None
#  2010-12-31                     None                       None
#
#             otherProvisions  advanceForFutureCapitalIncrease
#  endDate
#  2025-12-31            None                             None
#  2024-12-31            None                             None
#  2023-12-31            None                             None
#  2022-12-31            None                             None
#  2021-12-31            None                             None
#  2020-12-31            None                             None
#  2019-12-31            None                             None
#  2018-12-31            None                             None
#  2017-12-31            None                             None
#  2016-12-31            None                             None
#  2015-12-31            None                             None
#  2014-12-31            None                             None
#  2013-12-31            None                             None
#  2012-12-31            None                             None
#  2011-12-31            None                             None
#  2010-12-31            None                             None
#
#  [16 rows x 127 columns]}

# %%
for ativo in dataframe_collection:
    nome_ativo = ativo[0]['ativo']
    df = ativo[0]['data']
    df.to_csv('balanco/'+nome_ativo)

# %%
import os
from pathlib import Path
import pandas as pd

# %%
lista_df = []

for filename in os.listdir('balanco'):
    
    # 2. Reconstruct the full absolute or relative path to the file
    full_path = os.path.join('balanco', filename)
    
    # 3. Check if the current item is actually a file (and not a subfolder)
    # if os.path.isfile(full_path):
        
    #     # 4. Open and process the file safely
    #     with open(full_path, "r", encoding="utf-8") as file:
    #         content = file.read()
    #         print(f"--- Content of {filename} ---")
    #         print(pd.read_csv(full_path))
    dicio = {
        'ativo':filename,
        'data':pd.read_csv(full_path)
    }

    lista_df.append(dicio)

# %%
print(lista_df[0]['ativo'])
print(len(lista_df[0]['data'].columns.tolist()))
print(lista_df[0]['data'].columns.tolist())
# Out:
# ABEV3
# 128
# ['endDate', 'type', 'cash', 'shortTermInvestments', 'netReceivables', 'inventory', 'otherCurrentAssets', 'totalCurrentAssets', 'longTermInvestments', 'propertyPlantEquipment', 'otherAssets', 'totalAssets', 'accountsPayable', 'shortLongTermDebt', 'otherCurrentLiab', 'longTermDebt', 'otherLiab', 'totalCurrentLiabilities', 'totalLiab', 'commonStock', 'retainedEarnings', 'treasuryStock', 'otherStockholderEquity', 'totalStockholderEquity', 'netTangibleAssets', 'goodWill', 'intangibleAssets', 'deferredLongTermAssetCharges', 'deferredLongTermLiab', 'minorityInterest', 'capitalSurplus', 'financialAssets', 'centralBankCompulsoryDeposit', 'financialAssetsMeasuredAtFairValueThroughProfitOrLoss', 'currentAndDeferredTaxes', 'investments', 'financialAssetsFVThroughOCI', 'financialAssetsAtAmortizedCost', 'accountsReceivableFromClients', 'otherAccountsReceivable', 'biologicalAssets', 'taxesToRecover', 'prepaidExpenses', 'longTermAssets', 'longTermRealizableAssets', 'longTermReceivables', 'longTermAccountsReceivableFromClients', 'longTermInventory', 'longTermBiologicalAssets', 'longTermDeferredTaxes', 'longTermPrepaidExpenses', 'creditsWithRelatedParties', 'shareholdings', 'investmentProperties', 'otherLongTermReceivables', 'otherNonCurrentAssets', 'creditsFromOperations', 'insuranceAndReinsurance', 'complementaryPension', 'securitiesAndCreditsReceivable', 'otherValuesAndAssets', 'compulsoryLoansAndDeposits', 'deferredSellingExpenses', 'nonCurrentAssets', 'longTermFinancialInvestmentsMeasuredAtFairValueThroughIncome', 'financialInvestmentsFVThroughOCI', 'financialInvestmentsMeasuredAtAmortizedCost', 'intangibleAsset', 'deferredTaxes', 'capitalization', 'otherOperations', 'financialLiabilitiesMeasuredAtFairValueThroughIncome', 'financialLiabilitiesAtAmortizedCost', 'provisions', 'taxLiabilities', 'otherLiabilities', 'shareholdersEquity', 'controllerShareholdersEquity', 'nonControllingShareholdersEquity', 'realizedShareCapital', 'capitalReserves', 'revaluationReserves', 'profitReserves', 'accumulatedProfitsOrLosses', 'equityValuationAdjustments', 'cumulativeConversionAdjustments', 'otherComprehensiveResults', 'currentLiabilities', 'socialAndLaborObligations', 'providers', 'nationalSuppliers', 'foreignSuppliers', 'taxObligations', 'loansAndFinancing', 'loansAndFinancingInNationalCurrency', 'loansAndFinancingInForeignCurrency', 'debentures', 'leaseFinancing', 'otherObligations', 'otherCurrentLiabilities', 'nonCurrentLiabilities', 'longTermLoansAndFinancing', 'longTermLoansAndFinancingInNationalCurrency', 'longTermLoansAndFinancingInForeignCurrency', 'longTermDebentures', 'longTermLeaseFinancing', 'otherLongTermObligations', 'longTermProvisions', 'otherNonCurrentLiabilities', 'profitsAndRevenuesToBeAppropriated', 'debitsFromOperations', 'debitsFromInsuranceAndReinsurance', 'debitsFromComplementaryPension', 'thirdPartyDeposits', 'technicalProvisions', 'otherDebits', 'longTermLiabilities', 'longTermAccountsPayable', 'longTermDebitsFromOperations', 'longTermTechnicalProvisions', 'longTermInsuranceAndReinsurance', 'longTermComplementaryPension', 'longTermCapitalization', 'otherLongTermProvisions', 'debitsFromCapitalization', 'debitsFromOtherOperations', 'otherProvisions', 'advanceForFutureCapitalIncrease']

# %%
lista_df[0]['data']
# Out:
#        endDate    type         cash  shortTermInvestments  netReceivables  \
# 0   2025-12-31  yearly  18638227000            1681692000      6351608000
# 1   2024-12-31  yearly  28595667000            1242001000      6269863000
# 2   2023-12-31  yearly  16059003000             277164000      5741457000
# 3   2022-12-31  yearly  14926435000             454497000      5349105000
# 4   2021-12-31  yearly  16627698000            1914607000      4791634000
# 5   2020-12-31  yearly  17090335000            1700028000      4303138000
# 6   2019-12-31  yearly  11900666000              14558000      4495525000
# 7   2018-12-31  yearly  11463498000              13391000      4879256000
# 8   2017-12-31  yearly  10354527000              11883000      4944831000
# 9   2016-12-31  yearly   7876849000             282771000      4368059000
# 10  2015-12-31  yearly  13620161000             215106000      4165670000
# 11  2014-12-31  yearly   9722067000             712958000      3028854000
# 12  2013-12-31  yearly  11285833000             288604000      3613506000
# 13  2012-12-31  yearly     48155000                     0        21490000
#
#       inventory  otherCurrentAssets  totalCurrentAssets  longTermInvestments  \
# 0   10520090000          2346060000         43875594000            485792000
# 1   11689767000          2070171000         54155784000            395393000
# 2    9619022000           915024000         36563050000            289063000
# 3   12923025000           810395000         37816710000            331939000
# 4   11000346000          1156042000         38627140000            305180000
# 5    7605905000          1062514000         35342615000            337427000
# 6    5978557000           645171970         27621136000            303423000
# 7    5401793000           681731000         25329605000            257135010
# 8    4318973000           945819000         24718074000            237960990
# 9    4347052000           817553000         23886850000            300115000
# 10   4338172000          1763268000         28314489000            714925000
# 11   3411284000          1489747000         20728420000             40448000
# 12   2795490000           302243000         20470014000             26452000
# 13            0                   0            71641000           1274660000
#
#     propertyPlantEquipment  ...  longTermDebitsFromOperations  \
# 0              27644318000  ...                           NaN
# 1              30170194000  ...                           NaN
# 2              26630156000  ...                           NaN
# 3              30055690000  ...                           NaN
# 4              29224262000  ...                           NaN
# 5              24768354000  ...                           NaN
# 6              22576298000  ...                           NaN
# 7              20096995000  ...                           NaN
# 8              18822326000  ...                           NaN
# 9              19153836000  ...                           NaN
# 10             19140088000  ...                           NaN
# 11             15740058000  ...                           NaN
# 12             13937759000  ...                           NaN
# 13                       0  ...                           NaN
#
#     longTermTechnicalProvisions  longTermInsuranceAndReinsurance  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# 5                           NaN                              NaN
# 6                           NaN                              NaN
# 7                           NaN                              NaN
# 8                           NaN                              NaN
# 9                           NaN                              NaN
# 10                          NaN                              NaN
# 11                          NaN                              NaN
# 12                          NaN                              NaN
# 13                          NaN                              NaN
#
#     longTermComplementaryPension  longTermCapitalization  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# 5                            NaN                     NaN
# 6                            NaN                     NaN
# 7                            NaN                     NaN
# 8                            NaN                     NaN
# 9                            NaN                     NaN
# 10                           NaN                     NaN
# 11                           NaN                     NaN
# 12                           NaN                     NaN
# 13                           NaN                     NaN
#
#     otherLongTermProvisions  debitsFromCapitalization  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
# 9                       NaN                       NaN
# 10                      NaN                       NaN
# 11                      NaN                       NaN
# 12                      NaN                       NaN
# 13                      NaN                       NaN
#
#     debitsFromOtherOperations  otherProvisions  \
# 0                         NaN              NaN
# 1                         NaN              NaN
# 2                         NaN              NaN
# 3                         NaN              NaN
# 4                         NaN              NaN
# 5                         NaN              NaN
# 6                         NaN              NaN
# 7                         NaN              NaN
# 8                         NaN              NaN
# 9                         NaN              NaN
# 10                        NaN              NaN
# 11                        NaN              NaN
# 12                        NaN              NaN
# 13                        NaN              NaN
#
#     advanceForFutureCapitalIncrease
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
#
# [14 rows x 128 columns]
