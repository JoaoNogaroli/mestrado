# %%
import os
from brapi import Brapi
import pandas as pd
import requests
import json
import numpy as np
from pathlib import Path

# %%
api_k = 'qyWJMQp7dX6TcaKH88xyiM'

# %%
client = Brapi(
    api_key=api_k,
    environment="production",  # 'production' ou 'sandbox'
    max_retries=2,  # Número de tentativas (padrão: 2)
    timeout=60.0,  # Timeout em segundos (padrão: 60)
)

# %%
lista_ativos1 = [
    "VALE3.SA", "ITUB4.SA", "PETR4.SA", "PETR3.SA", "AXIA3.SA", "BBDC4.SA", "SBSP3.SA", "B3SA3.SA",
    "ITSA4.SA", "BPAC11.SA", "WEGE3.SA", "BBAS3.SA", "EMBJ3.SA", "ABEV3.SA", "EQTL3.SA", "RENT3.SA",
    "RDOR3.SA", "ENEV3.SA", "PRIO3.SA", "VBBR3.SA", "SUZB3.SA", "RADL3.SA", "AXIA7.SA", "VIVT3.SA",
    "UGPA3.SA", "BBDC3.SA", "GGBR4.SA", "CPLE3.SA", "CMIG4.SA", "TIMS3.SA", "TOTS3.SA", "BBSE3.SA",
    "RAIL3.SA", "ENGI11.SA", "AXIA6.SA", "MOTV3.SA", "KLBN11.SA", "LREN3.SA", "ALOS3.SA", "MBRF3.SA",
    "SANB11.SA", "ASAI3.SA", "EGIE3.SA", "ISAE4.SA", "CSAN3.SA", "CSMG3.SA", "MULT3.SA", "CXSE3.SA",
    "SMFT3.SA", "TAEE11.SA", "PSSA3.SA", "CPFE3.SA", "CMIN3.SA", "BRAV3.SA", "CYRE3.SA", "GOAU4.SA",
    "FLRY3.SA", "NATU3.SA", "HYPE3.SA", "COGN3.SA", "CURY3.SA", "CSNA3.SA", "IGTI11.SA", "BRAP4.SA",
    "DIRR3.SA", "IRBR3.SA", "POMO4.SA", "MGLU3.SA", "MRVE3.SA", "VIVA3.SA", "AURE3.SA", "SLCE3.SA",
    "YDUQ3.SA", "AZZA3.SA", "RECV3.SA", "USIM5.SA", "HAPV3.SA", "CEAB3.SA", "BRKM5.SA", "BEEF3.SA",
    "RENT4.SA", "VAMO3.SA", "CYRE4.SA", "PCAR3.SA", "RAIZ4.SA",
]
lista_ativos = []
for item in lista_ativos1:
    lista_ativos.append(item[:-3])

# %%
try:    
    dataframe_stock = []
    url = "https://brapi.dev/api/v2/macro?symbols=selic&startDate=2016-01-01&endDate=2026-12-31&limit=10000"
    print(url)
    response = requests.request("GET", url, headers = {
    "Authorization": api_k
    })
    print(response.json())
    info_final = {
        'macro':'selic',
        'data':pd.DataFrame(response.json()['results'][0]['observations']).set_index('date')
    }
    dataframe_stock.append(info_final)

    dataframe_stock[0]['data'].rename(columns={'value':'valor_anual'}, inplace=True)
    dataframe_stock[0]['data']['valor_diario'] = np.power(1+ dataframe_stock[0]['data']['valor_anual'], 1/252) - 1

    dataframe_stock[0]['data'].to_csv('macro/'+'selic')
except Exception as e:
    print("problema: ",e)
    pass
# Out:
# https://brapi.dev/api/v2/macro?symbols=selic&startDate=2016-01-01&endDate=2026-12-31&limit=10000
 'value': 14.5}, {'date': '2026-05-11', 'value': 14.5}, {'date': '2026-05-10', 'value': 14.5}, {'date': '2026-05-09', 'value': 14.5}, {'date': '2026-05-08', 'value': 14.5}, {'date': '2026-05-07', 'value': 14.5}, {'date': '2026-05-06', 'value': 14.5}, {'date': '2026-05-05', 'value': 14.5}, {'date': '2026-05-04', 'value': 14.5}, {'date': '2026-05-03', 'value': 14.5}, {'date': '2026-05-02', 'value': 14.5}, {'date': '2026-05-01', 'value': 14.5}, {'date': '2026-04-30', 'value': 14.5}, {'date': '2026-04-29', 'value': 14.75}, {'date': '2026-04-28', 'value': 14.75}, {'date': '2026-04-27', 'value': 14.75}, {'date': '2026-04-26', 'value': 14.75}, {'date': '2026-04-25', 'value': 14.75}, {'date': '2026-04-24', 'value': 14.75}, {'date': '2026-04-23', 'value': 14.75}, {'date': '2026-04-22', 'value': 14.75}, {'date': '2026-04-21', 'value': 14.75}, {'date': '2026-04-20', 'value': 14.75}, {'date': '2026-04-19', 'value': 14.75}, {'date': '2026-04-18', 'value': 14.75}, {'date': '2026-04-17', 'value': 14.75}, {'date': '2026-04-16', 'value': 14.75}, {'date': '2026-04-15', 'value': 14.75}, {'date': '2026-04-14', 'value': 14.75}, {'date': '2026-04-13', 'value': 14.75}, {'date': '2026-04-12', 'value': 14.75}, {'date': '2026-04-11', 'value': 14.75}, {'date': '2026-04-10', 'value':  ...

# %%
info_final
# Out:
# {'macro': 'selic',
#  'data':             valor_anual  valor_diario
#  date
#  2026-07-10        14.25       0.01087
#  2026-07-09        14.25       0.01087
#  2026-07-08        14.25       0.01087
#  2026-07-07        14.25       0.01087
#  2026-07-06        14.25       0.01087
#  ...                 ...           ...
#  2016-01-05        14.25       0.01087
#  2016-01-04        14.25       0.01087
#  2016-01-03        14.25       0.01087
#  2016-01-02        14.25       0.01087
#  2016-01-01        14.25       0.01087
#
#  [3844 rows x 2 columns]}

# %%
for filename in os.listdir('macro'):
    
    # 2. Reconstruct the full absolute or relative path to the file
    full_path = os.path.join('macro', filename)
    
    # 3. Check if the current item is actually a file (and not a subfolder)
    # if os.path.isfile(full_path):
        
    #     # 4. Open and process the file safely
    #     with open(full_path, "r", encoding="utf-8") as file:
    #         content = file.read()
    #         print(f"--- Content of {filename} ---")
    #         print(pd.read_csv(full_path))
    dicio = {
        'ativo':filename,
        'data':pd.read_csv(full_path)
    }

    # lista_df.append(dicio)

# %%
dicio['data']
# Out:
#             date  valor_anual  valor_diario
# 0     2026-07-06        14.25       0.01087
# 1     2026-07-05        14.25       0.01087
# 2     2026-07-04        14.25       0.01087
# 3     2026-07-03        14.25       0.01087
# 4     2026-07-02        14.25       0.01087
# ...          ...          ...           ...
# 3835  2016-01-05        14.25       0.01087
# 3836  2016-01-04        14.25       0.01087
# 3837  2016-01-03        14.25       0.01087
# 3838  2016-01-02        14.25       0.01087
# 3839  2016-01-01        14.25       0.01087
#
# [3840 rows x 3 columns]
