# %%
import os
from brapi import Brapi
from dotenv import load_dotenv
import pandas as pd
import requests
import json

from pathlib import Path

# %%
api_k = 'qyWJMQp7dX6TcaKH88xyiM'

# %%
client = Brapi(
    api_key=api_k,
    environment="production",  # 'production' ou 'sandbox'
    max_retries=2,  # Número de tentativas (padrão: 2)
    timeout=60.0,  # Timeout em segundos (padrão: 60)
)

# %%
lista_ativos = [
"ALOS3",
"ABEV3",
"ANIM3",
"ASAI3",
"AURE3",
"AXIA3",
"AZZA3",
"B3SA3",
"BBSE3",
"BBDC3",
"BBDC4",
"BRAP4",
"SAUD3",
"BBAS3",
"BRKM5",
"BRAV3",
"BPAC11",
"CXSE3",
"CBAV3",
"CEAB3",
"CMIG4",
"COGN3",
"CSMG3",
"CPLE3",
"CSAN3",
"CPFE3",
"CMIN3",
"CURY3",
"CVCB3",
"CYRE3",
"DIRR3",
"ECOR3",
"EMBJ3",
"ENGI11",
"ENEV3",
"EGIE3",
"EQTL3",
"EZTC3",
"FLRY3",
"GGBR4",
"GOAU4",
"GGPS3",
"GMAT3",
"HAPV3",
"HYPE3",
"IGTI11",
"INTB3",
"IRBR3",
"ISAE4",
"ITSA4",
"ITUB3",
"ITUB4",
"JHSF3",
"KLBN11",
"RENT3",
"LREN3",
"MGLU3",
"POMO4",
"MBRF3",
"BEEF3",
"MOTV3",
"MDNE3",
"MOVI3",
"MRVE3",
"MULT3",
"NATU3",
"ORVR3",
"PETR3",
"PETR4",
"RECV3",
"AUAU3",
"PSSA3",
"PRIO3",
"RADL3",
"RAPT4",
"RDOR3",
"RAIL3",
"SBSP3",
"SAPR11",
"SANB11",
"SMTO3",
"CSNA3",
"SIMH3",
"SLCE3",
"SMFT3",
"SUZB3",
"TAEE11",
"VIVT3",
"TEND3",
"TIMS3",
"TOTS3",
"UGPA3",
"USIM5",
"VALE3",
"VAMO3",
"VBBR3",
"VIVA3",
"WEGE3",
"YDUQ3",
]
print(f"Tamanho da Lista de ativos IBRX: {len(lista_ativos)}")
# lista_ativos = []
# for item in lista_ativos1:
#     lista_ativos.append(item[:-3])
# Out:
# Tamanho da Lista de ativos IBRX: 99

# %%
dataframe_collection = []
ativos_problema = []

for stock in lista_ativos:
    # ticker = stock.stock
    try:    
        ticker = stock

        dataframe_stock = []

        
        url = f"https://brapi.dev/api/v2/stocks/financial-data?symbols={ticker}&period=annual&mode=history"
        print(url)
        response = requests.request("GET", url, headers = {
        "Authorization": api_k
        })

        
            
        
        # print(response.json()['results'])
        info_final = {
            'ativo':stock,
            'data':pd.DataFrame(response.json()['results'][0]['data']).set_index('endDate')
        }
        # print(info_final)
        dataframe_stock.append(info_final)

        dataframe_collection.append(dataframe_stock)
    except Exception as e:
        print(e)
        print("Ticker com problema: ",ticker)
        ativos_problema.append(ticker)

        continue
# Out:
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ALOS3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ABEV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ANIM3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ASAI3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=AURE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=AXIA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=AZZA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=B3SA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BBSE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BBDC3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BBDC4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BRAP4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SAUD3&period=annual&mode=history
# "None of ['endDate'] are in the columns"
# Ticker com problema:  SAUD3
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BBAS3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BRKM5&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BRAV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BPAC11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CXSE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CBAV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CEAB3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CMIG4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=COGN3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CSMG3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CPLE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CSAN3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CPFE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CMIN3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CURY3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CVCB3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CYRE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=DIRR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ECOR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=EMBJ3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ENGI11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ENEV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=EGIE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=EQTL3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=EZTC3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=FLRY3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=GGBR4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=GOAU4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=GGPS3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=GMAT3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=HAPV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=HYPE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=IGTI11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=INTB3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=IRBR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ISAE4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ITSA4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ITUB3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ITUB4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=JHSF3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=KLBN11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=RENT3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=LREN3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MGLU3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=POMO4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MBRF3&period=annual&mode=history
# "None of ['endDate'] are in the columns"
# Ticker com problema:  MBRF3
# https://brapi.dev/api/v2/stocks/financial-data?symbols=BEEF3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MOTV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MDNE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MOVI3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MRVE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=MULT3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=NATU3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=ORVR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=PETR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=PETR4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=RECV3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=AUAU3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=PSSA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=PRIO3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=RADL3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=RAPT4&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=RDOR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=RAIL3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SBSP3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SAPR11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SANB11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SMTO3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=CSNA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SIMH3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SLCE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SMFT3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=SUZB3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=TAEE11&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=VIVT3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=TEND3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=TIMS3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=TOTS3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=UGPA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=USIM5&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=VALE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=VAMO3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=VBBR3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=VIVA3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=WEGE3&period=annual&mode=history
# https://brapi.dev/api/v2/stocks/financial-data?symbols=YDUQ3&period=annual&mode=history

# %%
for ativo in dataframe_collection:
    nome_ativo = ativo[0]['ativo']
    df = ativo[0]['data']
    df.to_csv('financeiros/'+nome_ativo)

# %%
lista_df = []

for filename in os.listdir('financeiros'):
    
    # 2. Reconstruct the full absolute or relative path to the file
    full_path = os.path.join('financeiros', filename)
    
    # 3. Check if the current item is actually a file (and not a subfolder)
    # if os.path.isfile(full_path):
        
    #     # 4. Open and process the file safely
    #     with open(full_path, "r", encoding="utf-8") as file:
    #         content = file.read()
    #         print(f"--- Content of {filename} ---")
    #         print(pd.read_csv(full_path))
    dicio = {
        'ativo':filename,
        'data':pd.read_csv(full_path)
    }

    lista_df.append(dicio)

# %%
print(lista_df[0]['data'].columns.tolist())
# Out:
# ['endDate', 'type', 'currentPrice', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'grossProfits', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'earningsGrowthAnnual', 'revenueGrowthAnnual', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'profitMargins', 'financialCurrency']

# %%
print(lista_df[1]['ativo'])
lista_df[1]['data']
# Out:
# ALOS3
#        endDate    type  currentPrice   totalCash  totalCashPerShare  \
# 0   2025-12-31  yearly           NaN  2430014000           4.819631
# 1   2024-12-31  yearly           NaN  3369105000           6.205334
# 2   2023-12-31  yearly           NaN  2133230000           3.716837
# 3   2022-12-31  yearly           NaN  2562121000           4.324447
# 4   2021-12-31  yearly           NaN  1246322000           4.689427
# 5   2020-12-31  yearly           NaN  1384700000           5.210090
# 6   2019-12-31  yearly           NaN  1200048000           4.515315
# 7   2018-12-31  yearly           NaN   280145000                NaN
# 8   2017-12-31  yearly           NaN   448429000                NaN
# 9   2016-12-31  yearly           NaN   256046000                NaN
# 10  2015-12-31  yearly           NaN   265144990                NaN
# 11  2014-12-31  yearly           NaN   315936000                NaN
# 12  2013-12-31  yearly           NaN   424431000           5.553648
# 13  2012-12-31  yearly           NaN   681976000           8.923604
# 14  2011-12-31  yearly           NaN   390918020           5.115132
# 15  2010-12-31  yearly           NaN    61566000           0.805586
#
#         ebitda    totalDebt  quickRatio  currentRatio  totalRevenue  ...  \
# 0   2174185000  10823013000    2.582123      2.582123    2859106000  ...
# 1   2071935000  10888810000    1.885644      1.885644    2739848000  ...
# 2   6097183000  10417028000    1.789294      1.789294    2712274000  ...
# 3    671672000   3392385000    3.215209      3.215209    1111321000  ...
# 4    681197950   2577246000    2.440440      2.440440     937677000  ...
# 5    505706020   2846768100    4.368225      4.368225     797585000  ...
# 6    372972000   3150954000    6.443372      6.443372     743186000  ...
# 7    562234000   1541447200    1.352046      1.352046     374112000  ...
# 8    384679000   1641573000    1.609044      1.609044     354856000  ...
# 9    389089980   1449487000    1.388053      1.388053     342294020  ...
# 10   337864000   1489975000    1.407308      1.407308     331180000  ...
# 11   424841000   1473798000    2.120398      2.120398     318724000  ...
# 12   550172030   1417074000    2.145402      2.145402     275753980  ...
# 13   418451000   1181680000    2.669286      2.669286     256851010  ...
# 14   451920000    733295040    3.493569      3.493569     219184990  ...
# 15   283177980    528961980    0.699240      0.699240     185008990  ...
#
#     operatingCashflow  earningsGrowth  revenueGrowth  earningsGrowthAnnual  \
# 0          1726228000        0.194206       0.043527              0.194206
# 1          1679910000       -0.793764       0.010166             -0.793764
# 2          1441890000       20.728678       1.440586             20.728678
# 3           929733000       -0.432910       0.185185             -0.432910
# 4           600245000        0.625755       0.175645              0.625755
# 5           303913000        6.675626       0.073197              6.675626
# 6           468296000       -0.883615       0.986533             -0.883615
# 7           187412000        0.367271       0.054264              0.367271
# 8           170940990        0.437184       0.036699              0.437184
# 9           162708000       -0.008289       0.033559             -0.008289
# 10          162575010       -0.381289       0.039081             -0.381289
# 11           73214000       -0.305292       0.155827             -0.305292
# 12           47551000        0.217861       0.073595              0.217861
# 13          174708000       -0.197009       0.171846             -0.197009
# 14          167748000        0.659914       0.184726              0.659914
# 15          106182000             NaN            NaN                   NaN
#
#     revenueGrowthAnnual  grossMargins  ebitdaMargins  operatingMargins  \
# 0              0.043527      0.738751       0.760442          0.538406
# 1              0.010166      0.737584       0.756223          0.530359
# 2              1.440586      0.695131       2.247997          1.995638
# 3              0.185185      0.721054       0.604391          0.422526
# 4              0.175645      0.679215       0.726474          0.522630
# 5              0.073197      0.662044       0.634047          0.401506
# 6              0.986533      0.730787       0.501856          0.341836
# 7              0.054264      0.790408       1.502849          1.497664
# 8              0.036699      0.765775       1.084043          1.077578
# 9              0.033559      0.753539       1.136713          1.128974
# 10             0.039081      0.759288       1.020182          1.012054
# 11             0.155827      0.762559       1.332943          1.325134
# 12             0.073595      0.787075       1.995155          1.986706
# 13             0.171846      0.831899       1.629158          1.622189
# 14             0.184726      0.832064       2.061820          2.055127
# 15                  NaN      0.812236       1.530617          1.524077
#
#     profitMargins  financialCurrency
# 0        0.330625                NaN
# 1        0.296359                NaN
# 2        1.288185                NaN
# 3        0.199892                NaN
# 4        0.339568                NaN
# 5        0.253858                NaN
# 6        0.076202                NaN
# 7        0.969881                NaN
# 8        0.710843                NaN
# 9        0.723872                NaN
# 10       0.616097                NaN
# 11       0.862097                NaN
# 12       1.336325                NaN
# 13       1.206127                NaN
# 14       1.662098                NaN
# 15       1.149998                NaN
#
# [16 rows x 26 columns]
