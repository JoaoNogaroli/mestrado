# %%
import os
from brapi import Brapi
from dotenv import load_dotenv
import pandas as pd
import requests
import json

from pathlib import Path

# %%
api_k = 'qyWJMQp7dX6TcaKH88xyiM'

# %%
client = Brapi(
    api_key=api_k,
    environment="production",  # 'production' ou 'sandbox'
    max_retries=2,  # Número de tentativas (padrão: 2)
    timeout=60.0,  # Timeout em segundos (padrão: 60)
)

# %%
lista_ativos1 = [
    "VALE3.SA", "ITUB4.SA", "PETR4.SA", "PETR3.SA", "AXIA3.SA", "BBDC4.SA", "SBSP3.SA", "B3SA3.SA",
    "ITSA4.SA", "BPAC11.SA", "WEGE3.SA", "BBAS3.SA", "EMBJ3.SA", "ABEV3.SA", "EQTL3.SA", "RENT3.SA",
    "RDOR3.SA", "ENEV3.SA", "PRIO3.SA", "VBBR3.SA", "SUZB3.SA", "RADL3.SA", "AXIA7.SA", "VIVT3.SA",
    "UGPA3.SA", "BBDC3.SA", "GGBR4.SA", "CPLE3.SA", "CMIG4.SA", "TIMS3.SA", "TOTS3.SA", "BBSE3.SA",
    "RAIL3.SA", "ENGI11.SA", "AXIA6.SA", "MOTV3.SA", "KLBN11.SA", "LREN3.SA", "ALOS3.SA", "MBRF3.SA",
    "SANB11.SA", "ASAI3.SA", "EGIE3.SA", "ISAE4.SA", "CSAN3.SA", "CSMG3.SA", "MULT3.SA", "CXSE3.SA",
    "SMFT3.SA", "TAEE11.SA", "PSSA3.SA", "CPFE3.SA", "CMIN3.SA", "BRAV3.SA", "CYRE3.SA", "GOAU4.SA",
    "FLRY3.SA", "NATU3.SA", "HYPE3.SA", "COGN3.SA", "CURY3.SA", "CSNA3.SA", "IGTI11.SA", "BRAP4.SA",
    "DIRR3.SA", "IRBR3.SA", "POMO4.SA", "MGLU3.SA", "MRVE3.SA", "VIVA3.SA", "AURE3.SA", "SLCE3.SA",
    "YDUQ3.SA", "AZZA3.SA", "RECV3.SA", "USIM5.SA", "HAPV3.SA", "CEAB3.SA", "BRKM5.SA", "BEEF3.SA",
    "RENT4.SA", "VAMO3.SA", "CYRE4.SA", "PCAR3.SA", "RAIZ4.SA",
]
lista_ativos = []
for item in lista_ativos1:
    lista_ativos.append(item[:-3])

# %%
dataframe_collection = []

for stock in lista_ativos:
    # ticker = stock.stock
    try:    
        ticker = stock

        dataframe_stock = []

        url = f"https://brapi.dev/api/v2/stocks/cash-flow?symbols={ticker}"
        print(url)
        response = requests.request("GET", url, headers = {
        "Authorization": api_k
        })

        
            
        

        info_final = {
            'ativo':stock,
            'data':pd.DataFrame(response.json()['results'][0]['data']).set_index('endDate')
        }
        dataframe_stock.append(info_final)

        dataframe_collection.append(dataframe_stock)
    except Exception as e:
        print("Ticker com problema: ",ticker)
        continue
# Out:
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=VALE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ITUB4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=PETR4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=PETR3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=AXIA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BBDC4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=SBSP3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=B3SA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ITSA4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BPAC11
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=WEGE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BBAS3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=EMBJ3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ABEV3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=EQTL3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RENT3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RDOR3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ENEV3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=PRIO3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=VBBR3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=SUZB3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RADL3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=AXIA7
# Ticker com problema:  AXIA7
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=VIVT3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=UGPA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BBDC3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=GGBR4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CPLE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CMIG4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=TIMS3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=TOTS3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BBSE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RAIL3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ENGI11
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=AXIA6
# Ticker com problema:  AXIA6
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=MOTV3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=KLBN11
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=LREN3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ALOS3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=MBRF3
# Ticker com problema:  MBRF3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=SANB11
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ASAI3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=EGIE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=ISAE4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CSAN3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CSMG3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=MULT3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CXSE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=SMFT3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=TAEE11
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=PSSA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CPFE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CMIN3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BRAV3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CYRE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=GOAU4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=FLRY3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=NATU3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=HYPE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=COGN3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CURY3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CSNA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=IGTI11
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BRAP4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=DIRR3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=IRBR3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=POMO4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=MGLU3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=MRVE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=VIVA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=AURE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=SLCE3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=YDUQ3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=AZZA3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RECV3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=USIM5
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=HAPV3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CEAB3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BRKM5
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=BEEF3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RENT4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=VAMO3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=CYRE4
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=PCAR3
# https://brapi.dev/api/v2/stocks/cash-flow?symbols=RAIZ4

# %%
for ativo in dataframe_collection:
    nome_ativo = ativo[0]['ativo']
    df = ativo[0]['data']
    df.to_csv('caixa/'+nome_ativo)

# %%
lista_df = []

for filename in os.listdir('caixa'):
    
    # 2. Reconstruct the full absolute or relative path to the file
    full_path = os.path.join('caixa', filename)
    
    # 3. Check if the current item is actually a file (and not a subfolder)
    # if os.path.isfile(full_path):
        
    #     # 4. Open and process the file safely
    #     with open(full_path, "r", encoding="utf-8") as file:
    #         content = file.read()
    #         print(f"--- Content of {filename} ---")
    #         print(pd.read_csv(full_path))
    dicio = {
        'ativo':filename,
        'data':pd.read_csv(full_path)
    }

    lista_df.append(dicio)

# %%
print(lista_df[0]['ativo'])
print(lista_df[0]['data'].columns.tolist())
# Out:
# ABEV3
# ['endDate', 'type', 'operatingCashFlow', 'incomeFromOperations', 'netIncomeBeforeTaxes', 'adjustmentsToProfitOrLoss', 'changesInAssetsAndLiabilities', 'otherOperatingActivities', 'cashGeneratedInOperations', 'investmentCashFlow', 'financingCashFlow', 'exchangeVariationWithoutCash', 'foreignExchangeRateWithoutCash', 'increaseOrDecreaseInCash', 'initialCashBalance', 'finalCashBalance', 'freeCashFlow']

# %%
lista_df[0]['data']['endDate']
# Out:
# 0     2025-12-31
# 1     2024-12-31
# 2     2023-12-31
# 3     2022-12-31
# 4     2021-12-31
# 5     2020-12-31
# 6     2019-12-31
# 7     2018-12-31
# 8     2017-12-31
# 9     2016-12-31
# 10    2015-12-31
# 11    2014-12-31
# 12    2013-12-31
# 13    2012-12-31
# Name: endDate, dtype: str
