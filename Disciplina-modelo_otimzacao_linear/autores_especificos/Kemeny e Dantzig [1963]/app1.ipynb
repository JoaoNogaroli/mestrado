# %%
import pandas as pd
import pyomo.environ as pyo
from pyomo.environ import SolverFactory
from pyomo.environ import *

# %%
model= pyo.ConcreteModel()

# %%
model.pprint()
# Out:
# 3 Var Declarations
#     galinhas : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :  None :  None : False :  True : NonNegativeIntegers
#     ovo : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :  None :  None : False :  True : NonNegativeIntegers
#     pintinho : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :  None :  None : False :  True : NonNegativeIntegers
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 60*galinhas + 120*ovo + 60*galinhas + 240*pintinho
#
# 4 Declarations: galinhas ovo pintinho obj

# %%
t = 1..4
# Out:
#   Cell In[17], line 1
#     t = 1..4
#           ^
# SyntaxError: invalid syntax
