# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
import yfinance as yf
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
anos = ['2025-12-31',
 '2024-12-31',
 '2023-12-31',
 '2022-12-31',
 '2021-12-31',
 '2020-12-31',
 '2019-12-31',
 '2018-12-31',
 '2017-12-31',
 '2016-12-31',
 '2015-12-31',
 ]

# %% [markdown]
# ## LER OS RETORNOS, SCORE e SELIC

# %%
# Retornos

dfs = {}
for ano in anos:
    ano_usado = ano.split('-')[0]
    nome = f'df_ativos_{ano_usado}.csv'
    caminho = Path('retornos_ativos_otimizacao') / nome
    dfs[ano_usado] = pd.read_csv(caminho).set_index('date')
    dfs[ano_usado] = dfs[ano_usado].drop(columns=dfs[ano_usado].columns[(dfs[ano_usado] == 0).all()])
    print(ano,'-',len(dfs[ano_usado].columns))
# Out:
# 2025-12-31 - 78
# 2024-12-31 - 78
# 2023-12-31 - 78
# 2022-12-31 - 77
# 2021-12-31 - 77
# 2020-12-31 - 73
# 2019-12-31 - 73
# 2018-12-31 - 70
# 2017-12-31 - 70
# 2016-12-31 - 67
# 2015-12-31 - 62

# %% [markdown]
# ## MODELO TESTE COM 1 ANO

# %%
retorno = dfs['2015']
lista_ativos = retorno.columns.tolist()
d_cov = retorno.cov()

# %%
#  --------- MODELO
model = pyo.ConcreteModel()
#---------VARIÁVEIS-----------
model.nome_ativos = pyo.Set(initialize = retorno.columns)
model.ativos = pyo.RangeSet(0, len(retorno.columns)-1)
model.dias = pyo.RangeSet(0, len(retorno)-1)
model.retornos_ativos = pyo.Param(model.dias, model.ativos, initialize=lambda model,dia, ativo: retorno.iloc[dia, ativo])    
model.sigma = pyo.Param(model.ativos, model.ativos, initialize=lambda model,a,b: d_cov.iloc[a,b])

model.z = pyo.Var(model.ativos, domain=pyo.NonNegativeReals)
model.k = pyo.Var(domain=pyo.NonNegativeReals)
model.y = pyo.Var(model.ativos, domain=pyo.Binary)
model.w = pyo.Var(model.ativos, domain=pyo.NonNegativeReals)
# Restrições-----Da linearização do sharpe------------
def res1(model):
    return sum(model.z[a] for a in model.ativos) == model.k
model.r_res1 = pyo.Constraint(rule=res1)
def res2(model):
    return sum(sum(model.retornos_ativos[d,a] * model.z[a] for a in model.ativos) for d in model.dias) == 1
model.r_res2 = pyo.Constraint(rule=res2)
# --------------------------
# Restrições ----- para resolver a bilinearidade da cardinalidade e peso
# estrutura dos pesos em situação normal
#   def ...(model):
#       return model.x[a] <= Peso_maximo * model.y[a]# 
#   
# na situação de z=kx (x=z/k) e substituindo na função, ficaria algo do tipo z[a] <= peso_maximo * model.k * model.y[a]
# e aqui teria o problema de bilinearidade Variavel continua * binária       
# e para resolver isso usa-se 


def res3(model):
    return model

#-----------------------

# Objetivo---------------
def obj1(model):
    return sum(model.sigma[a,b] * model.z[a] * model.z[b] for a in model.ativos for b in model.ativos)
model.r_obj1 = pyo.Objective(rule=obj1, sense=pyo.minimize)

# ------------------- solver
opt = SolverFactory('cplex', executable='C:\\Program Files\\IBM\\ILOG\\CPLEX_Studio_Community222\\cplex\\bin\\x64_win64\\cplex.exe')
res = opt.solve(model,tee=False)

# %%
for a in model.ativos:
    print(a, model.z[a].value/model.k.value)
# Out:
# 0 7.224552491215238e-09
# 1 7.540775313357171e-09
# 2 7.726353099509225e-09
# 3 1.1201509922122478e-08
# 4 2.5565038941404028e-08
# 5 4.803828819188706e-09
# 6 7.918472207296148e-09
# 7 8.319636928692076e-09
# 8 6.334802953784447e-09
# 9 5.50136932766196e-09
# 10 3.2617064617804176e-09
# 11 0.11447848512379098
# 12 6.4744127447068355e-09
# 13 2.066243636622738e-08
# 14 2.956474027162076e-08
# 15 4.263827815352164e-09
# 16 0.03871644787156198
# 17 2.3701153172263298e-08
# 18 4.464919817917408e-08
# 19 1.2849074451560927e-08
# 20 1.4510550442633412e-08
# 21 0.020830770108244554
# 22 4.40909187161477e-09
# 23 1.481449622675012e-08
# 24 2.214338369638885e-05
# 25 3.2553084577424326e-08
# 26 2.7440138221182084e-08
# 27 0.147196676182486
# 28 7.7444046668541e-09
# 29 3.751667647230821e-09
# 30 0.15706864006567936
# 31 4.940301940917501e-08
# 32 7.88338279051475e-09
# 33 6.422275389520218e-09
# 34 6.362912734505851e-09
# 35 1.5032625815771128e-08
# 36 6.6940871338422335e-09
# 37 5.5071862171839335e-09
# 38 0.04004885927361981
# 39 9.738717354793494e-09
# 40 0.3340004116643018
# 41 2.1121581053699084e-08
# 42 5.199752815790922e-09
# 43 4.49497174395125e-09
# 44 0.016756167767084197
# 45 1.0724350038989136e-08
# 46 5.612716339866482e-09
# 47 2.3034753199470765e-08
# 48 6.655692288252948e-09
# 49 7.797045827008024e-09
# 50 7.426245258544416e-09
# 51 0.053026065378156274
# 52 7.336878392248071e-09
# 53 0.07785469079194214
# 54 5.4961094210523035e-09
# 55 1.565750638670781e-08
# 56 5.347326004642532e-09
# 57 8.128912718511285e-09
# 58 2.575605649335526e-09
# 59 5.150645925188486e-09
# 60 4.482803871228862e-08
# 61 5.9707750732633285e-09

# %% [markdown]
# ## MODEO FINAL COM TODOS OS ANOS

# %%
y = []
carteiras_anuais = {}
melhor_pesos = None
historico = []
carteiras_criadas = []
for a in anos:
    y.append(a.split('-')[0])
print("=-"*48)
print("Anos totais: ",y)
print("=-"*48)
lista_ativos_finais = {}
for an in anos:
    ano = an.split("-")[0]
    ano_int = int(ano)
    print("COMEÇANDO ANO NOVO: ",ano)
    #deletar modelo
    if 'model' in locals():
        del model
        print('Modelo Antigo deletado \n Iniciando Novo')
    else:
        print("Nao consta model")
        pass
    try:
        # retorno_usado = pd.DataFrame(eval(df_usado))
        df_usado = dfs[str(ano_int)]
        retorno_usado = df_usado.copy()

        # COV
        df_cov = retorno_usado.cov()

        # Lista ativos
        lista_ativos_finais[ano] = retorno_usado.columns.tolist()
    except Exception as e:
            print("=========ERRRRRRRRRRRROR")
            print(e)    

    print("# ------ CRIAÇÃO DO MODELO")
    print("## Carteira criada para o ano: ",ano_int+1)
    print("## UTILIZANDO DADOS DE RETORNO DE: ",ano)

    #  --------- MODELO
    model = pyo.ConcreteModel()
    #---------VARIÁVEIS-----------
    model.nome_ativos = pyo.Set(initialize = retorno_usado.columns)
    model.ativos = pyo.RangeSet(0, len(retorno_usado.columns)-1)
    model.dias = pyo.RangeSet(0, len(retorno_usado)-1)
    model.retornos_ativos = pyo.Param(model.dias, model.ativos, initialize=lambda model,dia, ativo: retorno_usado.iloc[dia, ativo])    
    model.sigma = pyo.Param(model.ativos, model.ativos, initialize=lambda model,a,b: df_cov.iloc[a,b])

    #linearizar Sharpe
    # z:= kx
    model.z = pyo.Var(model.ativos, domain=pyo.NonNegativeReals)
    model.k = pyo.Var(domain=pyo.NonNegativeReals)
    model.y = pyo.Var(model.ativos, domain=pyo.Binary)
    model.w = pyo.Var(model.ativos, domain=pyo.NonNegativeReals)
    model.KMAX = pyo.Param(initialize=100)

    # Com a problemática de cardinalidade y e bilinearidade, resolve-se
    # PESO
    # antes era model.x[a] <= model.pesomax * model.y[a]
    #  z=kx  -> model.z[a] <= model.pesomax * modely[a] * model.k[a]
    # CARDINALIDADE
    # era sum(model.y[a] ...) >= e <=

    # Com y=0
    def res_y_zero(model,a):
        return model.w[a] <= model.KMAX * model.y[a]
    model.y_zero = pyo.Constraint(model.ativos, rule=res_y_zero)

    # com y=1
        #  segundo teto
    def res_y_1_teto2(model,a):
        return model.w[a] <= model.k 
    model.res_teto2 = pyo.Constraint(model.ativos, rule=res_y_1_teto2)

        # Limite inf 1
    def limite_1(model,a):
        return model.w[a] >= model.k - model.KMAX*(1-model.y[a])
    model.r_limite1 = pyo.Constraint(model.ativos, rule=limite_1)

    #  PESOS MIN MAX
    def pesomin(model,a):
        return model.z[a] >= 0.02*model.w[a]
    model.r_pesomin = pyo.Constraint(model.ativos, rule=pesomin)

    def pesomax(model,a):
        return model.z[a] <= model.w[a]
    model.r_pesomax = pyo.Constraint(model.ativos, rule=pesomax)

    #  cardinalidade
    def card_min(model):
        return sum(model.y[a] for a in model.ativos) >= 10
    model.r_cardmin = pyo.Constraint(rule=card_min)
    def card_max(model):
        return sum(model.y[a] for a in model.ativos) <= 10
    model.r_card_max = pyo.Constraint(rule=card_max)

    # Restrições Sharpe
    def restricao_z(model):
        return sum(model.z[a] for a in model.ativos) == model.k
    model.r_restricao_z = pyo.Constraint(rule=restricao_z)

    def restricao_z_retorno(model):
        return sum(sum(model.retornos_ativos[t,a]*model.z[a] for a in model.ativos) for t in model.dias) == 1
    model.r_res_z_retorno = pyo.Constraint(rule=restricao_z_retorno)

    def obj_r(model):
        var = sum(model.sigma[a,b]*model.z[a]*model.z[b] for a in model.ativos for b in model.ativos)
        return var
    model.obj = pyo.Objective(rule=obj_r, sense=pyo.minimize)

    # ------------------- solver
    opt = SolverFactory('cplex', executable='C:\\Program Files\\IBM\\ILOG\\CPLEX_Studio_Community222\\cplex\\bin\\x64_win64\\cplex.exe')
    res = opt.solve(model,tee=False)

    melhor_pesos = {list(model.nome_ativos.data())[a]:(model.z[a].value/model.k.value) for a in model.ativos}
    carteiras_anuais[ano_int+1] = {
        'pesos':  melhor_pesos,
        # 'sharpe_anual': s_lo*np.sqrt(252),
    }
    print(f"{ano} -> {melhor_pesos}")
    print("+-="*30)
    if 'model' in locals():
        del model
        print('DELETADO DPS DO WHILE')
    else:
        print("Nao consta model")
        pass
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Anos totais:  ['2025', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015']
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# COMEÇANDO ANO NOVO:  2025
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2026
# ## UTILIZANDO DADOS DE RETORNO DE:  2025
# 2025 -> {'ABEV3': 0.16399730959517303, 'ALOS3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.18863016808460253, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.019999999999999993, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.019999999999999993, 'PETR4': 0.1424246933540179, 'POMO4': 0.0, 'PRIO3': 0.15775350414833705, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.08771797862021022, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.0, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.04377523293277628, 'VALE3': 0.11054285465910935, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.06515825860577353, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2024
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2025
# ## UTILIZANDO DADOS DE RETORNO DE:  2024
# 2024 -> {'ABEV3': 0.0, 'ALOS3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.38266458333295267, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.05777962171698744, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.07173260780572348, 'CPFE3': 0.11892305058509513, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.15553337885163526, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.019999999999999997, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.019999999999999997, 'PETR4': 0.12984080972292003, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.020000000000000004, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.023525947984685856, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2023
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2024
# ## UTILIZANDO DADOS DE RETORNO DE:  2023
# 2023 -> {'ABEV3': 0.0, 'ALOS3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.020051202602722928, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.02739623764675536, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.2579252321619159, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.18910456873658485, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.1541387943408698, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.05289981101762919, 'POMO4': 0.020000000000000007, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.06529881175944002, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.09948671254459729, 'USIM5': 0.11369862918948469, 'VALE3': 0.0, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2022
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2023
# ## UTILIZANDO DADOS DE RETORNO DE:  2022
# 2022 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.019999999999999997, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.26174999339874055, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.06599432643474452, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.02393978673492533, 'CVCB3': 0.0, 'CXSE3': 0.02, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.4318573747930772, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.027792217119170366, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.019999999999999993, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.0, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.019999999999999993, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.10866630151934209, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2021
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2022
# ## UTILIZANDO DADOS DE RETORNO DE:  2021
# 2021 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.02, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.14386507013115576, 'BEEF3': 0.02, 'BPAC11': 0.0, 'BRAP4': 0.2009588535032633, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.020000000000000004, 'EMBJ3': 0.0, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0286493924470532, 'PETR4': 0.02, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.019999999999999993, 'SUZB3': 0.0, 'TAEE11': 0.2585994243121768, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VBBR3': 0.0, 'VIVT3': 0.2679272596063508, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2020
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2021
# ## UTILIZANDO DADOS DE RETORNO DE:  2020
# 2020 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.06637780110875091, 'BRKM5': 0.08697715079219322, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.10627202112235068, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.07385378726249657, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.019999999999999993, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.032888178965840786, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.2264683928590432, 'SMTO3': 0.0, 'SUZB3': 0.07080974150617035, 'TAEE11': 0.29635292638315436, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.019999999999999997, 'VIVT3': 0.0, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2019
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2020
# ## UTILIZANDO DADOS DE RETORNO DE:  2019
# 2019 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.019999999999999997, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.020000000000000004, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.020000000000000004, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.02, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.02, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.4044653768664295, 'SMTO3': 0.0, 'SUZB3': 0.019999999999999997, 'TAEE11': 0.019999999999999997, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.02, 'WEGE3': 0.43553462313357033, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2018
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2019
# ## UTILIZANDO DADOS DE RETORNO DE:  2018
# 2018 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.05532310937515714, 'BRAP4': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.1441522221386187, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.08147254491634268, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.17380555291482058, 'ISAE4': 0.13984333802995666, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.04405440900307226, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.04753152688782703, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.19905308340232755, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.02870577180656371, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.08605844152531378, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2017
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2018
# ## UTILIZANDO DADOS DE RETORNO DE:  2017
# 2017 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.06057680740335647, 'BRAP4': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.02927874980418783, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.0, 'ENGI11': 0.13143074362217352, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.33215015654433216, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.020553274270598176, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.06228324462397689, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.13817866407177282, 'SMTO3': 0.0, 'SUZB3': 0.10178087458391828, 'TAEE11': 0.0, 'TEND3': 0.07576840207653725, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.04799908299914665, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2016
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2017
# ## UTILIZANDO DADOS DE RETORNO DE:  2016
# 2016 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.043521719351440384, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.054672571577106255, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.3879939252655922, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.040782372784804684, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.03747006920433382, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.030705398714334767, 'MOTV3': 0.0, 'MOVI3': 0.07234839023034363, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.13495052112476885, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0569417525116455, 'SMTO3': 0.0, 'SUZB3': 0.1406132792356298, 'TAEE11': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2015
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2016
# ## UTILIZANDO DADOS DE RETORNO DE:  2015
# 2015 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BRAP4': 0.0, 'BRKM5': 0.11391667279755469, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.038228430504712786, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.020088973055954286, 'ECOR3': 0.0, 'EMBJ3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.1466366769418281, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.15713519747158297, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.040229881100535415, 'MOTV3': 0.0, 'MRVE3': 0.33427597583806284, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.020000000000000007, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SBSP3': 0.051836715320343354, 'SLCE3': 0.0, 'SMTO3': 0.07765147696942563, 'SUZB3': 0.0, 'TAEE11': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE

# %%
carteiras_anuais
# Out:
# {2026: {'pesos': {'ABEV3': 0.16399730959517303,
#    'ALOS3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.18863016808460253,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.019999999999999993,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.019999999999999993,
#    'PETR4': 0.1424246933540179,
#    'POMO4': 0.0,
#    'PRIO3': 0.15775350414833705,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.08771797862021022,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.0,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.04377523293277628,
#    'VALE3': 0.11054285465910935,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.06515825860577353,
#    'YDUQ3': 0.0}},
#  2025: {'pesos': {'ABEV3': 0.0,
#    'ALOS3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.38266458333295267,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.05777962171698744,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.07173260780572348,
#    'CPFE3': 0.11892305058509513,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.15553337885163526,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.019999999999999997,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.019999999999999997,
#    'PETR4': 0.12984080972292003,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.020000000000000004,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.023525947984685856,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2024: {'pesos': {'ABEV3': 0.0,
#    'ALOS3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.020051202602722928,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.02739623764675536,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.2579252321619159,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.18910456873658485,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.1541387943408698,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.05289981101762919,
#    'POMO4': 0.020000000000000007,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.06529881175944002,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.09948671254459729,
#    'USIM5': 0.11369862918948469,
#    'VALE3': 0.0,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2023: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.019999999999999997,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.26174999339874055,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.06599432643474452,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.02393978673492533,
#    'CVCB3': 0.0,
#    'CXSE3': 0.02,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.4318573747930772,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.027792217119170366,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.019999999999999993,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.0,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.019999999999999993,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.10866630151934209,
#    'YDUQ3': 0.0}},
#  2022: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.02,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.14386507013115576,
#    'BEEF3': 0.02,
#    'BPAC11': 0.0,
#    'BRAP4': 0.2009588535032633,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.020000000000000004,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0286493924470532,
#    'PETR4': 0.02,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.019999999999999993,
#    'SUZB3': 0.0,
#    'TAEE11': 0.2585994243121768,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VBBR3': 0.0,
#    'VIVT3': 0.2679272596063508,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2021: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.06637780110875091,
#    'BRKM5': 0.08697715079219322,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.10627202112235068,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.07385378726249657,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.019999999999999993,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.032888178965840786,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.2264683928590432,
#    'SMTO3': 0.0,
#    'SUZB3': 0.07080974150617035,
#    'TAEE11': 0.29635292638315436,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.019999999999999997,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2020: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.019999999999999997,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.020000000000000004,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.020000000000000004,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.02,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.02,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.4044653768664295,
#    'SMTO3': 0.0,
#    'SUZB3': 0.019999999999999997,
#    'TAEE11': 0.019999999999999997,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.02,
#    'WEGE3': 0.43553462313357033,
#    'YDUQ3': 0.0}},
#  2019: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.05532310937515714,
#    'BRAP4': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.1441522221386187,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.08147254491634268,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.17380555291482058,
#    'ISAE4': 0.13984333802995666,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.04405440900307226,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.04753152688782703,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.19905308340232755,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.02870577180656371,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.08605844152531378,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}},
#  2018: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.06057680740335647,
#    'BRAP4': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.02927874980418783,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.0,
#    'ENGI11': 0.13143074362217352,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.33215015654433216,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.020553274270598176,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.06228324462397689,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.13817866407177282,
#    'SMTO3': 0.0,
#    'SUZB3': 0.10178087458391828,
#    'TAEE11': 0.0,
#    'TEND3': 0.07576840207653725,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.04799908299914665,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}},
#  2017: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.043521719351440384,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.054672571577106255,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.3879939252655922,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.040782372784804684,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.03747006920433382,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.030705398714334767,
#    'MOTV3': 0.0,
#    'MOVI3': 0.07234839023034363,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.13495052112476885,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0569417525116455,
#    'SMTO3': 0.0,
#    'SUZB3': 0.1406132792356298,
#    'TAEE11': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}},
#  2016: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BRAP4': 0.0,
#    'BRKM5': 0.11391667279755469,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.038228430504712786,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.020088973055954286,
#    'ECOR3': 0.0,
#    'EMBJ3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.1466366769418281,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.15713519747158297,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.040229881100535415,
#    'MOTV3': 0.0,
#    'MRVE3': 0.33427597583806284,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.020000000000000007,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SBSP3': 0.051836715320343354,
#    'SLCE3': 0.0,
#    'SMTO3': 0.07765147696942563,
#    'SUZB3': 0.0,
#    'TAEE11': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}}}

# %%
linhas = []
for an in anos:
    an = int(an.split('-')[0])+1
    print(an)
    for k, v in carteiras_anuais[an]['pesos'].items():
        # print(v)
        if v >= 0.05 :
            linhas.append({'ano': an, 'ativo': k, 'peso': round(v, 4)})

df_portfolios = pd.DataFrame(linhas)

# # visões instantâneas:
# df_portfolios[df_portfolios['ano'] == 2016].sort_values('peso', ascending=False)  # uma carteira
# df_portfolios.pivot(index='ativo', columns='ano', values='peso')                  # matriz ativo × ano
# df_portfolios.groupby('ativo')['ano'].count().sort_values(ascending=False)
# Out:
# 2026
# 2025
# 2024
# 2023
# 2022
# 2021
# 2020
# 2019
# 2018
# 2017
# 2016

# %%
aaa = 2019
print(df_portfolios[df_portfolios['ano']==aaa])
print(df_portfolios[df_portfolios['ano']==aaa]['peso'].sum())
# Out:
#      ano   ativo    peso
# 37  2019  BPAC11  0.0553
# 38  2019   CPFE3  0.1442
# 39  2019   ENEV3  0.0815
# 40  2019   IRBR3  0.1738
# 41  2019   ISAE4  0.1398
# 42  2019  SAPR11  0.1991
# 43  2019   TOTS3  0.0861
# 0.8798
