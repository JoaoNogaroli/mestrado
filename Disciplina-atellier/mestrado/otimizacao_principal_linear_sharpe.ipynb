# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
import yfinance as yf
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
anos = ['2025-12-31',
 '2024-12-31',
 '2023-12-31',
 '2022-12-31',
 '2021-12-31',
 '2020-12-31',
 '2019-12-31',
 '2018-12-31',
 '2017-12-31',
 '2016-12-31',
 '2015-12-31',
 ]

# %% [markdown]
# ## LER OS RETORNOS, SCORE e SELIC

# %%
# Retornos

dfs = {}
for ano in anos:
    ano_usado = ano.split('-')[0]
    nome = f'df_ativos_{ano_usado}.csv'
    caminho = Path('retornos_ativos_otimizacao') / nome
    dfs[ano_usado] = pd.read_csv(caminho).set_index('date')
    dfs[ano_usado] = dfs[ano_usado].drop(columns=dfs[ano_usado].columns[(dfs[ano_usado] == 0).all()])
    print(ano,'-',len(dfs[ano_usado].columns))
# Out:
# 2025-12-31 - 78
# 2024-12-31 - 78
# 2023-12-31 - 78
# 2022-12-31 - 77
# 2021-12-31 - 77
# 2020-12-31 - 73
# 2019-12-31 - 73
# 2018-12-31 - 70
# 2017-12-31 - 70
# 2016-12-31 - 67
# 2015-12-31 - 62

# %%
vb_cardinalidade_max = 10
vb_cardinalidade_min = 10
vb_peso_maximo = 0.20
vb_peso_minimo = 0.02
vb_theta = 0.5

# %% [markdown]
# ## MODEO FINAL COM TODOS OS ANOS

# %%
y = []
carteiras_anuais = {}
melhor_pesos = None
historico = []
carteiras_criadas = []
for a in anos:
    y.append(a.split('-')[0])
print("=-"*48)
print("Anos totais: ",y)
print("=-"*48)
lista_ativos_finais = {}
for an in anos:
    ano = an.split("-")[0]
    ano_int = int(ano)
    print("COMEÇANDO ANO NOVO: ",ano)
    #deletar modelo
    if 'model' in locals():
        del model
        print('Modelo Antigo deletado \n Iniciando Novo')
    else:
        print("Nao consta model")
        pass
    try:
        # retorno_usado = pd.DataFrame(eval(df_usado))
        df_usado = dfs[str(ano_int)]
        retorno_usado = df_usado.copy()

        # COV
        df_cov = retorno_usado.cov()

        # Lista ativos
        lista_ativos_finais[ano] = retorno_usado.columns.tolist()
    except Exception as e:
            print("=========ERRRRRRRRRRRROR")
            print(e)    

    print("# ------ CRIAÇÃO DO MODELO")
    print("## Carteira criada para o ano: ",ano_int+1)
    print("## UTILIZANDO DADOS DE RETORNO DE: ",ano)

    #  --------- MODELO
    model = pyo.ConcreteModel()
    #---------VARIÁVEIS-----------
    model.nome_ativos = pyo.Set(initialize = retorno_usado.columns)
    model.ativos = pyo.RangeSet(0, len(retorno_usado.columns)-1)
    model.dias = pyo.RangeSet(0, len(retorno_usado)-1)
    model.retornos_ativos = pyo.Param(model.dias, model.ativos, initialize=lambda model,dia, ativo: retorno_usado.iloc[dia, ativo])    
    model.sigma = pyo.Param(model.ativos, model.ativos, initialize=lambda model,a,b: df_cov.iloc[a,b])

    #linearizar Sharpe
    # z:= kx
    model.z = pyo.Var(model.ativos, domain=pyo.NonNegativeReals)
    model.k = pyo.Var(domain=pyo.NonNegativeReals)
    model.y = pyo.Var(model.ativos, domain=pyo.Binary)
    model.w = pyo.Var(model.ativos, domain=pyo.NonNegativeReals)
    model.KMAX = pyo.Param(initialize=100)

    # Com a problemática de cardinalidade y e bilinearidade, resolve-se
    # PESO
    # antes era model.x[a] <= model.pesomax * model.y[a]
    #  z=kx  -> model.z[a] <= model.pesomax * modely[a] * model.k[a]
    # CARDINALIDADE
    # era sum(model.y[a] ...) >= e <=

    # Com y=0
    def res_y_zero(model,a):
        return model.w[a] <= model.KMAX * model.y[a]
    model.y_zero = pyo.Constraint(model.ativos, rule=res_y_zero)

    # com y=1
        #  segundo teto
    def res_y_1_teto2(model,a):
        return model.w[a] <= model.k 
    model.res_teto2 = pyo.Constraint(model.ativos, rule=res_y_1_teto2)

        # Limite inf 1
    def limite_1(model,a):
        return model.w[a] >= model.k - model.KMAX*(1-model.y[a])
    model.r_limite1 = pyo.Constraint(model.ativos, rule=limite_1)

    #  PESOS MIN MAX
    def pesomin(model,a):
        return model.z[a] >= vb_peso_minimo * model.w[a]
    model.r_pesomin = pyo.Constraint(model.ativos, rule=pesomin)

    def pesomax(model,a):
        return model.z[a] <= vb_peso_maximo * model.w[a]
    model.r_pesomax = pyo.Constraint(model.ativos, rule=pesomax)

    #  cardinalidade
    def card_min(model):
        return sum(model.y[a] for a in model.ativos) >= vb_cardinalidade_min
    model.r_cardmin = pyo.Constraint(rule=card_min)
    def card_max(model):
        return sum(model.y[a] for a in model.ativos) <= vb_cardinalidade_max
    model.r_card_max = pyo.Constraint(rule=card_max)

    # Restrições Sharpe
    def restricao_z(model):
        return sum(model.z[a] for a in model.ativos) == model.k
    model.r_restricao_z = pyo.Constraint(rule=restricao_z)

    def restricao_z_retorno(model):
        return sum(sum(model.retornos_ativos[t,a]*model.z[a] for a in model.ativos) for t in model.dias) == 1
    model.r_res_z_retorno = pyo.Constraint(rule=restricao_z_retorno)

    def obj_r(model):
        var = sum(model.sigma[a,b]*model.z[a]*model.z[b] for a in model.ativos for b in model.ativos)
        return var
    model.obj = pyo.Objective(rule=obj_r, sense=pyo.minimize)

    # ------------------- solver
    opt = SolverFactory('cplex', executable='C:\\Program Files\\IBM\\ILOG\\CPLEX_Studio_Community222\\cplex\\bin\\x64_win64\\cplex.exe')
    res = opt.solve(model,tee=False)

    melhor_pesos = {list(model.nome_ativos.data())[a]:(model.z[a].value/model.k.value) for a in model.ativos}
    carteiras_anuais[ano_int+1] = {
        'pesos':  melhor_pesos,
        # 'sharpe_anual': s_lo*np.sqrt(252),
    }
    print(f"{ano} -> {melhor_pesos}")
    print("+-="*30)
    if 'model' in locals():
        del model
        print('DELETADO DPS DO WHILE')
    else:
        print("Nao consta model")
        pass
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Anos totais:  ['2025', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015']
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# COMEÇANDO ANO NOVO:  2025
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2026
# ## UTILIZANDO DADOS DE RETORNO DE:  2025
# 2025 -> {'ABEV3': 0.16239703695630206, 'ALOS3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.02, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.18869631628620495, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.019999999999999997, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.16191857433187068, 'POMO4': 0.0, 'PRIO3': 0.15747043148970521, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.08946101458214269, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.0, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0432142138429631, 'VALE3': 0.09283611125336563, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.06400630125744547, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2024
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2025
# ## UTILIZANDO DADOS DE RETORNO DE:  2024
# 2024 -> {'ABEV3': 0.0, 'ALOS3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.20000000000000012, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.06044599033061828, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.08296277403807478, 'CPFE3': 0.17826902330005684, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.17885217849057064, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.019999999999999997, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.019999999999999997, 'PETR4': 0.1727210517458659, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.02, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.06674898209481345, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2023
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2024
# ## UTILIZANDO DADOS DE RETORNO DE:  2023
# 2023 -> {'ABEV3': 0.0, 'ALOS3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.019999999999999997, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.03845596335211499, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.2, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.19019661921784145, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.176862760983216, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.05982237726611827, 'POMO4': 0.019999999999999997, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.07974571495798978, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.10021318115437505, 'USIM5': 0.11470338306834431, 'VALE3': 0.0, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2022
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2023
# ## UTILIZANDO DADOS DE RETORNO DE:  2022
# 2022 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.2, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.19999999999999998, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.02, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.19999999999999998, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.02, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.07378031972279672, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0767996086167488, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.019999999999999997, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.019999999999999993, 'VBBR3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.16942007166045456, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2021
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2022
# ## UTILIZANDO DADOS DE RETORNO DE:  2021
# 2021 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.020000000000000014, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.17739787984457558, 'BEEF3': 0.037876455842215606, 'BPAC11': 0.0, 'BRAP4': 0.20000000000000004, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CXSE3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.08596991489855257, 'EMBJ3': 0.0, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IGTI11': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.03875574941465587, 'PETR4': 0.02000000000000001, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMFT3': 0.0, 'SMTO3': 0.020000000000000007, 'SUZB3': 0.0, 'TAEE11': 0.2000000000000002, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VBBR3': 0.0, 'VIVT3': 0.20000000000000012, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2020
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2021
# ## UTILIZANDO DADOS DE RETORNO DE:  2020
# 2020 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.07891602763270904, 'BRKM5': 0.11023080208674993, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.10167213195193733, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.08338788241156718, 'ENEV3': 0.0, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0778507364739364, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.038787849574530235, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.20000000000000012, 'SMTO3': 0.0, 'SUZB3': 0.08915456986856994, 'TAEE11': 0.2000000000000001, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.020000000000000004, 'VIVT3': 0.0, 'WEGE3': 0.0, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2019
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2020
# ## UTILIZANDO DADOS DE RETORNO DE:  2019
# 2019 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0, 'BRAV3': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.19999999999999998, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.02, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.02, 'LREN3': 0.0, 'MDNE3': 0.0, 'MGLU3': 0.02, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.09999999999999994, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.2, 'SMTO3': 0.0, 'SUZB3': 0.019999999999999997, 'TAEE11': 0.019999999999999997, 'TEND3': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.20000000000000004, 'WEGE3': 0.2, 'YDUQ3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2018
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2019
# ## UTILIZANDO DADOS DE RETORNO DE:  2018
# 2018 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0553231093751571, 'BRAP4': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.14415222213861864, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.08147254491634233, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.17380555291482055, 'ISAE4': 0.1398433380299569, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.04405440900307228, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.047531526887827, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SAPR11': 0.19905308340232755, 'SBSP3': 0.0, 'SLCE3': 0.0, 'SMTO3': 0.0, 'SUZB3': 0.0287057718065637, 'TAEE11': 0.0, 'TEND3': 0.0, 'TOTS3': 0.08605844152531376, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2017
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2018
# ## UTILIZANDO DADOS DE RETORNO DE:  2017
# 2017 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.07461353595999903, 'BRAP4': 0.0, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.02, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.0, 'ENGI11': 0.1738350311596338, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'IRBR3': 0.2, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.0, 'MOTV3': 0.0, 'MOVI3': 0.0, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.04863087103074273, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.09286830002921423, 'SANB11': 0.0, 'SAPR11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.13903734061996145, 'SMTO3': 0.0, 'SUZB3': 0.11020624368374761, 'TAEE11': 0.0, 'TEND3': 0.07768879870794086, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.06311987880876038, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2016
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2017
# ## UTILIZANDO DADOS DE RETORNO DE:  2016
# 2016 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.05896741287864726, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BPAC11': 0.0, 'BRAP4': 0.0680320811444558, 'BRKM5': 0.0, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.20000000000000007, 'CPLE3': 0.0, 'CSAN3': 0.0, 'CSMG3': 0.05658789084031952, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.0, 'ECOR3': 0.0, 'EGIE3': 0.0, 'EMBJ3': 0.0, 'ENEV3': 0.04649440283556163, 'ENGI11': 0.0, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.0, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.0, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.04011855139483386, 'MOTV3': 0.0, 'MOVI3': 0.0982228248661806, 'MRVE3': 0.0, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.1748396950120902, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAIL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SBSP3': 0.0, 'SLCE3': 0.08516052305262685, 'SMTO3': 0.0, 'SUZB3': 0.17157661797528426, 'TAEE11': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE
# COMEÇANDO ANO NOVO:  2015
# Nao consta model
# # ------ CRIAÇÃO DO MODELO
# ## Carteira criada para o ano:  2016
# ## UTILIZANDO DADOS DE RETORNO DE:  2015
# 2015 -> {'ABEV3': 0.0, 'ANIM3': 0.0, 'AXIA3': 0.0, 'AZZA3': 0.0, 'B3SA3': 0.0, 'BBAS3': 0.0, 'BBDC3': 0.0, 'BBDC4': 0.0, 'BBSE3': 0.0, 'BEEF3': 0.0, 'BRAP4': 0.0, 'BRKM5': 0.12323074259195689, 'CMIG4': 0.0, 'COGN3': 0.0, 'CPFE3': 0.0, 'CPLE3': 0.0, 'CSAN3': 0.07325720898579877, 'CSMG3': 0.0, 'CSNA3': 0.0, 'CVCB3': 0.0, 'CYRE3': 0.0, 'DIRR3': 0.054161813009368176, 'ECOR3': 0.0, 'EMBJ3': 0.0, 'ENGI11': 0.030726619076116922, 'EQTL3': 0.0, 'EZTC3': 0.0, 'FLRY3': 0.1503617268810684, 'GGBR4': 0.0, 'GOAU4': 0.0, 'HYPE3': 0.17417808365146634, 'ISAE4': 0.0, 'ITSA4': 0.0, 'ITUB3': 0.0, 'ITUB4': 0.0, 'JHSF3': 0.0, 'KLBN11': 0.0, 'LREN3': 0.0, 'MGLU3': 0.035741924052836146, 'MOTV3': 0.0, 'MRVE3': 0.19999999999999998, 'MULT3': 0.0, 'PETR3': 0.0, 'PETR4': 0.0, 'POMO4': 0.0, 'PRIO3': 0.0, 'PSSA3': 0.0, 'RADL3': 0.0, 'RAPT4': 0.0, 'RENT3': 0.0, 'SANB11': 0.0, 'SBSP3': 0.06922795033816966, 'SLCE3': 0.0, 'SMTO3': 0.08911393141321879, 'SUZB3': 0.0, 'TAEE11': 0.0, 'TOTS3': 0.0, 'UGPA3': 0.0, 'USIM5': 0.0, 'VALE3': 0.0, 'VIVT3': 0.0, 'WEGE3': 0.0}
# +-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=+-=
# DELETADO DPS DO WHILE

# %%
carteiras_anuais
# Out:
# {2026: {'pesos': {'ABEV3': 0.16239703695630206,
#    'ALOS3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.02,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.18869631628620495,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.019999999999999997,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.16191857433187068,
#    'POMO4': 0.0,
#    'PRIO3': 0.15747043148970521,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.08946101458214269,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.0,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0432142138429631,
#    'VALE3': 0.09283611125336563,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.06400630125744547,
#    'YDUQ3': 0.0}},
#  2025: {'pesos': {'ABEV3': 0.0,
#    'ALOS3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.20000000000000012,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.06044599033061828,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.08296277403807478,
#    'CPFE3': 0.17826902330005684,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.17885217849057064,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.019999999999999997,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.019999999999999997,
#    'PETR4': 0.1727210517458659,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.02,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.06674898209481345,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2024: {'pesos': {'ABEV3': 0.0,
#    'ALOS3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.019999999999999997,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.03845596335211499,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.2,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.19019661921784145,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.176862760983216,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.05982237726611827,
#    'POMO4': 0.019999999999999997,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.07974571495798978,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.10021318115437505,
#    'USIM5': 0.11470338306834431,
#    'VALE3': 0.0,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2023: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.2,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.19999999999999998,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.02,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.19999999999999998,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.02,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.07378031972279672,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0767996086167488,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.019999999999999997,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.019999999999999993,
#    'VBBR3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.16942007166045456,
#    'YDUQ3': 0.0}},
#  2022: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.020000000000000014,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.17739787984457558,
#    'BEEF3': 0.037876455842215606,
#    'BPAC11': 0.0,
#    'BRAP4': 0.20000000000000004,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CXSE3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.08596991489855257,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IGTI11': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.03875574941465587,
#    'PETR4': 0.02000000000000001,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMFT3': 0.0,
#    'SMTO3': 0.020000000000000007,
#    'SUZB3': 0.0,
#    'TAEE11': 0.2000000000000002,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VBBR3': 0.0,
#    'VIVT3': 0.20000000000000012,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2021: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.07891602763270904,
#    'BRKM5': 0.11023080208674993,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.10167213195193733,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.08338788241156718,
#    'ENEV3': 0.0,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0778507364739364,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.038787849574530235,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.20000000000000012,
#    'SMTO3': 0.0,
#    'SUZB3': 0.08915456986856994,
#    'TAEE11': 0.2000000000000001,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.020000000000000004,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0,
#    'YDUQ3': 0.0}},
#  2020: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0,
#    'BRAV3': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.19999999999999998,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.02,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.02,
#    'LREN3': 0.0,
#    'MDNE3': 0.0,
#    'MGLU3': 0.02,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.09999999999999994,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.2,
#    'SMTO3': 0.0,
#    'SUZB3': 0.019999999999999997,
#    'TAEE11': 0.019999999999999997,
#    'TEND3': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.20000000000000004,
#    'WEGE3': 0.2,
#    'YDUQ3': 0.0}},
#  2019: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0553231093751571,
#    'BRAP4': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.14415222213861864,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.08147254491634233,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.17380555291482055,
#    'ISAE4': 0.1398433380299569,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.04405440900307228,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.047531526887827,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SAPR11': 0.19905308340232755,
#    'SBSP3': 0.0,
#    'SLCE3': 0.0,
#    'SMTO3': 0.0,
#    'SUZB3': 0.0287057718065637,
#    'TAEE11': 0.0,
#    'TEND3': 0.0,
#    'TOTS3': 0.08605844152531376,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}},
#  2018: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.07461353595999903,
#    'BRAP4': 0.0,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.02,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.0,
#    'ENGI11': 0.1738350311596338,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'IRBR3': 0.2,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.0,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.04863087103074273,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.09286830002921423,
#    'SANB11': 0.0,
#    'SAPR11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.13903734061996145,
#    'SMTO3': 0.0,
#    'SUZB3': 0.11020624368374761,
#    'TAEE11': 0.0,
#    'TEND3': 0.07768879870794086,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.06311987880876038,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}},
#  2017: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.05896741287864726,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BPAC11': 0.0,
#    'BRAP4': 0.0680320811444558,
#    'BRKM5': 0.0,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.20000000000000007,
#    'CPLE3': 0.0,
#    'CSAN3': 0.0,
#    'CSMG3': 0.05658789084031952,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.0,
#    'ECOR3': 0.0,
#    'EGIE3': 0.0,
#    'EMBJ3': 0.0,
#    'ENEV3': 0.04649440283556163,
#    'ENGI11': 0.0,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.0,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.0,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.04011855139483386,
#    'MOTV3': 0.0,
#    'MOVI3': 0.0982228248661806,
#    'MRVE3': 0.0,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.1748396950120902,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAIL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SBSP3': 0.0,
#    'SLCE3': 0.08516052305262685,
#    'SMTO3': 0.0,
#    'SUZB3': 0.17157661797528426,
#    'TAEE11': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}},
#  2016: {'pesos': {'ABEV3': 0.0,
#    'ANIM3': 0.0,
#    'AXIA3': 0.0,
#    'AZZA3': 0.0,
#    'B3SA3': 0.0,
#    'BBAS3': 0.0,
#    'BBDC3': 0.0,
#    'BBDC4': 0.0,
#    'BBSE3': 0.0,
#    'BEEF3': 0.0,
#    'BRAP4': 0.0,
#    'BRKM5': 0.12323074259195689,
#    'CMIG4': 0.0,
#    'COGN3': 0.0,
#    'CPFE3': 0.0,
#    'CPLE3': 0.0,
#    'CSAN3': 0.07325720898579877,
#    'CSMG3': 0.0,
#    'CSNA3': 0.0,
#    'CVCB3': 0.0,
#    'CYRE3': 0.0,
#    'DIRR3': 0.054161813009368176,
#    'ECOR3': 0.0,
#    'EMBJ3': 0.0,
#    'ENGI11': 0.030726619076116922,
#    'EQTL3': 0.0,
#    'EZTC3': 0.0,
#    'FLRY3': 0.1503617268810684,
#    'GGBR4': 0.0,
#    'GOAU4': 0.0,
#    'HYPE3': 0.17417808365146634,
#    'ISAE4': 0.0,
#    'ITSA4': 0.0,
#    'ITUB3': 0.0,
#    'ITUB4': 0.0,
#    'JHSF3': 0.0,
#    'KLBN11': 0.0,
#    'LREN3': 0.0,
#    'MGLU3': 0.035741924052836146,
#    'MOTV3': 0.0,
#    'MRVE3': 0.19999999999999998,
#    'MULT3': 0.0,
#    'PETR3': 0.0,
#    'PETR4': 0.0,
#    'POMO4': 0.0,
#    'PRIO3': 0.0,
#    'PSSA3': 0.0,
#    'RADL3': 0.0,
#    'RAPT4': 0.0,
#    'RENT3': 0.0,
#    'SANB11': 0.0,
#    'SBSP3': 0.06922795033816966,
#    'SLCE3': 0.0,
#    'SMTO3': 0.08911393141321879,
#    'SUZB3': 0.0,
#    'TAEE11': 0.0,
#    'TOTS3': 0.0,
#    'UGPA3': 0.0,
#    'USIM5': 0.0,
#    'VALE3': 0.0,
#    'VIVT3': 0.0,
#    'WEGE3': 0.0}}}

# %%
linhas = []
for an in anos:
    an = int(an.split('-')[0])+1
    print(an)
    for k, v in carteiras_anuais[an]['pesos'].items():
        # print(v)
        if v >= vb_peso_minimo:
            linhas.append({'ano': an, 'ativo': k, 'peso': round(v, 4)})

df_portfolios = pd.DataFrame(linhas)

# # visões instantâneas:
# df_portfolios[df_portfolios['ano'] == 2016].sort_values('peso', ascending=False)  # uma carteira
# df_portfolios.pivot(index='ativo', columns='ano', values='peso')                  # matriz ativo × ano
# df_portfolios.groupby('ativo')['ano'].count().sort_values(ascending=False)
# Out:
# 2026
# 2025
# 2024
# 2023
# 2022
# 2021
# 2020
# 2019
# 2018
# 2017
# 2016

# %%
df_portfolios
# Out:
#       ano  ativo    peso
# 0    2026  ABEV3  0.1624
# 1    2026  BRAP4  0.0200
# 2    2026  CSMG3  0.1887
# 3    2026  PETR4  0.1619
# 4    2026  PRIO3  0.1575
# ..    ...    ...     ...
# 96   2016  HYPE3  0.1742
# 97   2016  MGLU3  0.0357
# 98   2016  MRVE3  0.2000
# 99   2016  SBSP3  0.0692
# 100  2016  SMTO3  0.0891
#
# [101 rows x 3 columns]

# %%
df_portfolios.to_csv('carteiras_linear_sharpe.csv')
