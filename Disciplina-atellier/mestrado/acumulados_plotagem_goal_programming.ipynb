# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df_carteira = pd.read_csv('carteiras_gp.csv').drop(columns=['Unnamed: 0'])

# %%
df_carteira
# Out:
#       ano  ativo    peso
# 0    2016  BRKM5  0.0200
# 1    2016  CSAN3  0.0200
# 2    2016  FLRY3  0.2000
# 3    2016  ISAE4  0.2000
# 4    2016  LREN3  0.0200
# ..    ...    ...     ...
# 105  2026  LREN3  0.0200
# 106  2026  MULT3  0.2000
# 107  2026  RENT3  0.2000
# 108  2026  SBSP3  0.1338
# 109  2026  VIVT3  0.0200
#
# [110 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = int(ano)-1
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'

    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_igual/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_igual/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Ativos do ano 2016: ['BRKM5', 'CSAN3', 'FLRY3', 'ISAE4', 'LREN3', 'MRVE3', 'RADL3', 'SBSP3', 'TAEE11', 'UGPA3']
# Carteira do ano 2016 testada para mesmo ano 2015
# date
# 2015-04-01    100.897850
# 2015-04-02    101.594859
# 2015-04-06    102.867061
# 2015-04-07    102.612350
# 2015-04-08    103.394820
#                  ...
# 2016-03-24    132.284833
# 2016-03-28    133.496151
# 2016-03-29    134.447362
# 2016-03-30    135.660280
# 2016-03-31    134.361448
# Length: 245, dtype: float64
# Ativos do ano 2017: ['BBSE3', 'CSAN3', 'CSMG3', 'ECOR3', 'EGIE3', 'ISAE4', 'MGLU3', 'VALE3', 'VIVT3', 'WEGE3']
# Carteira do ano 2017 testada para mesmo ano 2016
# date
# 2016-04-01    100.471526
# 2016-04-04     97.428724
# 2016-04-05     97.591226
# 2016-04-06     96.239344
# 2016-04-07     95.943985
#                  ...
# 2017-03-27    154.987386
# 2017-03-28    153.956916
# 2017-03-29    155.234130
# 2017-03-30    154.472058
# 2017-03-31    152.854191
# Length: 251, dtype: float64
# Ativos do ano 2018: ['ANIM3', 'AZZA3', 'B3SA3', 'BRAP4', 'BRKM5', 'CSMG3', 'CSNA3', 'SBSP3', 'SLCE3', 'USIM5']
# Carteira do ano 2018 testada para mesmo ano 2017
# date
# 2017-04-03     99.315311
# 2017-04-04    100.877775
# 2017-04-05    100.067879
# 2017-04-06     98.890449
# 2017-04-07     99.672477
#                  ...
# 2018-03-23    152.861454
# 2018-03-26    150.220546
# 2018-03-27    146.606661
# 2018-03-28    146.643447
# 2018-03-29    150.363216
# Length: 244, dtype: float64
# Ativos do ano 2019: ['B3SA3', 'CSAN3', 'MULT3', 'PETR3', 'PETR4', 'RAIL3', 'RAPT4', 'SBSP3', 'USIM5', 'VALE3']
# Carteira do ano 2019 testada para mesmo ano 2018
# date
# 2018-04-02     99.016481
# 2018-04-03     98.256518
# 2018-04-04     97.530028
# 2018-04-05     99.323018
# 2018-04-06     99.796612
#                  ...
# 2019-03-25    128.397423
# 2019-03-26    131.222984
# 2019-03-27    125.639687
# 2019-03-28    127.728236
# 2019-03-29    129.719970
# Length: 245, dtype: float64
# Ativos do ano 2020: ['AZZA3', 'B3SA3', 'BEEF3', 'CMIG4', 'CSAN3', 'CSMG3', 'CYRE3', 'DIRR3', 'SAPR11', 'WEGE3']
# Carteira do ano 2020 testada para mesmo ano 2019
# date
# 2019-04-01    100.616224
# 2019-04-02    100.095537
# 2019-04-03    100.415120
# 2019-04-04    102.380441
# 2019-04-05    102.932881
#                  ...
# 2020-03-25    105.631778
# 2020-03-26    113.905451
# 2020-03-27    109.711676
# 2020-03-30    110.716166
# 2020-03-31    106.333629
# Length: 250, dtype: float64
# Ativos do ano 2021: ['CPFE3', 'CSMG3', 'CSNA3', 'CVCB3', 'CYRE3', 'EGIE3', 'ENGI11', 'SLCE3', 'VALE3', 'WEGE3']
# Carteira do ano 2021 testada para mesmo ano 2020
# date
# 2020-04-01     96.866764
# 2020-04-02     95.364816
# 2020-04-03     93.024139
# 2020-04-06     97.327526
# 2020-04-07     99.763812
#                  ...
# 2021-03-25    170.105036
# 2021-03-26    172.122597
# 2021-03-29    173.277307
# 2021-03-30    174.365063
# 2021-03-31    177.088056
# Length: 246, dtype: float64
# Ativos do ano 2022: ['AXIA3', 'AZZA3', 'B3SA3', 'BEEF3', 'BRAP4', 'BRAV3', 'BRKM5', 'PETR3', 'PETR4', 'VALE3']
# Carteira do ano 2022 testada para mesmo ano 2021
# date
# 2021-04-01     99.640593
# 2021-04-05    101.835138
# 2021-04-06    102.075409
# 2021-04-07    104.353345
# 2021-04-08    103.696904
#                  ...
# 2022-03-25    146.442502
# 2022-03-28    145.158686
# 2022-03-29    146.593620
# 2022-03-30    148.243328
# 2022-03-31    147.882926
# Length: 249, dtype: float64
# Ativos do ano 2023: ['ANIM3', 'BEEF3', 'KLBN11', 'LREN3', 'MOTV3', 'MULT3', 'PETR3', 'PETR4', 'SBSP3', 'TOTS3']
# Carteira do ano 2023 testada para mesmo ano 2022
# date
# 2022-04-01    101.940644
# 2022-04-04    101.093105
# 2022-04-05    100.946227
# 2022-04-06     99.925420
# 2022-04-07    102.142708
#                  ...
# 2023-03-27    106.021698
# 2023-03-28    107.462920
# 2023-03-29    107.144453
# 2023-03-30    109.183643
# 2023-03-31    107.984877
# Length: 251, dtype: float64
# Ativos do ano 2024: ['COGN3', 'CSMG3', 'ECOR3', 'IGTI11', 'MULT3', 'TOTS3', 'VBBR3', 'VIVT3', 'WEGE3', 'YDUQ3']
# Carteira do ano 2024 testada para mesmo ano 2023
# date
# 2023-04-03     98.068024
# 2023-04-04     99.096560
# 2023-04-05     99.988430
# 2023-04-06    100.174317
# 2023-04-10    100.923479
#                  ...
# 2024-03-22    149.008723
# 2024-03-25    147.959956
# 2024-03-26    146.571969
# 2024-03-27    146.100500
# 2024-03-28    145.082769
# Length: 246, dtype: float64
# Ativos do ano 2025: ['ANIM3', 'BBSE3', 'CMIG4', 'COGN3', 'CPFE3', 'FLRY3', 'MGLU3', 'MULT3', 'TAEE11', 'TEND3']
# Carteira do ano 2025 testada para mesmo ano 2024
# date
# 2024-04-01    99.347293
# 2024-04-02    98.762037
# 2024-04-03    97.588238
# 2024-04-04    98.517755
# 2024-04-05    97.522704
#                 ...
# 2025-03-25    87.265413
# 2025-03-26    87.705171
# 2025-03-27    88.648555
# 2025-03-28    87.548063
# 2025-03-31    85.815504
# Length: 251, dtype: float64
# Ativos do ano 2026: ['ALOS3', 'ANIM3', 'AZZA3', 'BBSE3', 'JHSF3', 'LREN3', 'MULT3', 'RENT3', 'SBSP3', 'VIVT3']
# Carteira do ano 2026 testada para mesmo ano 2025
# date
# 2025-04-01    101.821976
# 2025-04-02    103.269050
# 2025-04-03    105.894682
# 2025-04-04    102.346450
# 2025-04-07    101.341701
#                  ...
# 2026-03-25    169.008576
# 2026-03-26    164.321016
# 2026-03-27    161.918728
# 2026-03-30    163.374774
# 2026-03-31    171.202745
# Length: 250, dtype: float64

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_frente/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_frente/acumulado_f_ibov/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
