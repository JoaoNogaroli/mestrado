# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df_carteira = pd.read_csv('carteiras_gp.csv').drop(columns=['Unnamed: 0'])

# %%
df_carteira
# Out:
#       ano   ativo  peso
# 0    2016   B3SA3  0.02
# 1    2016   COGN3  0.02
# 2    2016   CSAN3  0.20
# 3    2016   FLRY3  0.10
# 4    2016   ISAE4  0.20
# ..    ...     ...   ...
# 105  2026  IGTI11  0.02
# 106  2026   JHSF3  0.20
# 107  2026   MULT3  0.02
# 108  2026   SBSP3  0.20
# 109  2026  TAEE11  0.02
#
# [110 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = int(ano)-1
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'

    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_igual/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_igual/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Ativos do ano 2016: ['B3SA3', 'COGN3', 'CSAN3', 'FLRY3', 'ISAE4', 'LREN3', 'MULT3', 'RADL3', 'TAEE11', 'UGPA3']
# Carteira do ano 2016 testada para mesmo ano 2015
# date
# 2015-04-01    101.641710
# 2015-04-02    101.975873
# 2015-04-06    102.340615
# 2015-04-07    102.253286
# 2015-04-08    102.876454
#                  ...
# 2016-03-24    120.748742
# 2016-03-28    122.303202
# 2016-03-29    123.301048
# 2016-03-30    123.733717
# 2016-03-31    122.799342
# Length: 245, dtype: float64
# Ativos do ano 2017: ['AXIA3', 'BBSE3', 'COGN3', 'CSAN3', 'CSMG3', 'ECOR3', 'HYPE3', 'ISAE4', 'VALE3', 'VIVT3']
# Carteira do ano 2017 testada para mesmo ano 2016
# date
# 2016-04-01    100.545306
# 2016-04-04     97.735265
# 2016-04-05     97.555583
# 2016-04-06     96.039329
# 2016-04-07     96.265152
#                  ...
# 2017-03-27    144.991494
# 2017-03-28    145.084777
# 2017-03-29    146.600158
# 2017-03-30    145.824029
# 2017-03-31    145.726121
# Length: 251, dtype: float64
# Ativos do ano 2018: ['ABEV3', 'ANIM3', 'CSMG3', 'ECOR3', 'ITSA4', 'MULT3', 'SAPR11', 'SBSP3', 'SLCE3', 'VIVT3']
# Carteira do ano 2018 testada para mesmo ano 2017
# date
# 2017-04-03    100.407222
# 2017-04-04    101.093736
# 2017-04-05    101.614039
# 2017-04-06    100.754681
# 2017-04-07    101.434298
#                  ...
# 2018-03-23    130.278987
# 2018-03-26    129.634115
# 2018-03-27    127.843210
# 2018-03-28    127.310158
# 2018-03-29    128.588355
# Length: 244, dtype: float64
# Ativos do ano 2019: ['ABEV3', 'AXIA3', 'B3SA3', 'CSAN3', 'CSNA3', 'ISAE4', 'MGLU3', 'MULT3', 'SBSP3', 'VALE3']
# Carteira do ano 2019 testada para mesmo ano 2018
# date
# 2018-04-02     99.162671
# 2018-04-03     99.012802
# 2018-04-04     98.054246
# 2018-04-05     98.772871
# 2018-04-06     97.933649
#                  ...
# 2019-03-25    121.598364
# 2019-03-26    123.749571
# 2019-03-27    119.004020
# 2019-03-28    121.359740
# 2019-03-29    122.712280
# Length: 245, dtype: float64
# Ativos do ano 2020: ['B3SA3', 'CMIG4', 'CPFE3', 'CPLE3', 'CSAN3', 'CSMG3', 'ITSA4', 'MOTV3', 'SAPR11', 'WEGE3']
# Carteira do ano 2020 testada para mesmo ano 2019
# date
# 2019-04-01    100.199585
# 2019-04-02     99.348124
# 2019-04-03    100.067450
# 2019-04-04    102.376881
# 2019-04-05    102.717155
#                  ...
# 2020-03-25     91.519443
# 2020-03-26    100.737914
# 2020-03-27     96.887139
# 2020-03-30     98.174897
# 2020-03-31     94.100442
# Length: 250, dtype: float64
# Ativos do ano 2021: ['BRAP4', 'CPFE3', 'CSMG3', 'CYRE3', 'ENGI11', 'ISAE4', 'ITSA4', 'SBSP3', 'SLCE3', 'TAEE11']
# Carteira do ano 2021 testada para mesmo ano 2020
# date
# 2020-04-01     97.070962
# 2020-04-02     96.678781
# 2020-04-03     94.906666
# 2020-04-06     99.529725
# 2020-04-07    101.835207
#                  ...
# 2021-03-25    151.046499
# 2021-03-26    152.689832
# 2021-03-29    154.244895
# 2021-03-30    156.199826
# 2021-03-31    157.133655
# Length: 246, dtype: float64
# Ativos do ano 2022: ['BRKM5', 'CSNA3', 'GOAU4', 'MOTV3', 'PETR3', 'PETR4', 'SAPR11', 'SBSP3', 'USIM5', 'VALE3']
# Carteira do ano 2022 testada para mesmo ano 2021
# date
# 2021-04-01     99.038442
# 2021-04-05    100.466684
# 2021-04-06    101.895131
# 2021-04-07    103.103830
# 2021-04-08    103.510372
#                  ...
# 2022-03-25    109.533178
# 2022-03-28    108.967869
# 2022-03-29    108.749174
# 2022-03-30    109.060161
# 2022-03-31    108.196488
# Length: 249, dtype: float64
# Ativos do ano 2023: ['B3SA3', 'BBSE3', 'BEEF3', 'GOAU4', 'MOTV3', 'MULT3', 'PETR3', 'PETR4', 'SBSP3', 'SUZB3']
# Carteira do ano 2023 testada para mesmo ano 2022
# date
# 2022-04-01    102.804393
# 2022-04-04    101.908081
# 2022-04-05    101.715519
# 2022-04-06    100.575421
# 2022-04-07    102.692732
#                  ...
# 2023-03-27    108.218795
# 2023-03-28    110.095929
# 2023-03-29    110.095560
# 2023-03-30    112.367570
# 2023-03-31    111.528541
# Length: 251, dtype: float64
# Ativos do ano 2024: ['ABEV3', 'ALOS3', 'BBSE3', 'CMIG4', 'CSMG3', 'ECOR3', 'IGTI11', 'MULT3', 'SAPR11', 'VBBR3']
# Carteira do ano 2024 testada para mesmo ano 2023
# date
# 2023-04-03     98.760298
# 2023-04-04    100.188540
# 2023-04-05    101.534302
# 2023-04-06    101.931431
# 2023-04-10    102.810785
#                  ...
# 2024-03-22    138.545172
# 2024-03-25    138.177021
# 2024-03-26    137.834073
# 2024-03-27    138.355401
# 2024-03-28    137.075099
# Length: 246, dtype: float64
# Ativos do ano 2025: ['ALOS3', 'ANIM3', 'B3SA3', 'COGN3', 'CPFE3', 'ENGI11', 'FLRY3', 'MULT3', 'PSSA3', 'TAEE11']
# Carteira do ano 2025 testada para mesmo ano 2024
# date
# 2024-04-01    99.308282
# 2024-04-02    99.358205
# 2024-04-03    98.791984
# 2024-04-04    98.942920
# 2024-04-05    98.377472
#                 ...
# 2025-03-25    94.521926
# 2025-03-26    94.676555
# 2025-03-27    95.235264
# 2025-03-28    94.737669
# 2025-03-31    93.886828
# Length: 251, dtype: float64
# Ativos do ano 2026: ['ABEV3', 'ALOS3', 'ANIM3', 'AZZA3', 'ECOR3', 'IGTI11', 'JHSF3', 'MULT3', 'SBSP3', 'TAEE11']
# Carteira do ano 2026 testada para mesmo ano 2025
# date
# 2025-04-01    101.361894
# 2025-04-02    102.227432
# 2025-04-03    105.832952
# 2025-04-04    101.338846
# 2025-04-07     99.230813
#                  ...
# 2026-03-25    181.065230
# 2026-03-26    176.767223
# 2026-03-27    173.905274
# 2026-03-30    175.961391
# 2026-03-31    184.596563
# Length: 250, dtype: float64

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_frente/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/goal_programming/ano_frente/acumulado_f_ibov/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
