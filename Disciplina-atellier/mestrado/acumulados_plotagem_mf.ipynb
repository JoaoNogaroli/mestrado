# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
import yfinance as yf
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carteiras_mf.csv').drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#       ano   ativo    peso
# 0    2016   ALOS3  0.0200
# 1    2016  BPAC11  0.1042
# 2    2016   BRAV3  0.0200
# 3    2016   DIRR3  0.0679
# 4    2016   FLRY3  0.1224
# ..    ...     ...     ...
# 105  2026   PRIO3  0.1650
# 106  2026   SLCE3  0.0752
# 107  2026   USIM5  0.0453
# 108  2026   VALE3  0.0737
# 109  2026   WEGE3  0.0696
#
# [110 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df[df['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = int(ano)-1
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/magic_formula_acumulados/ano_igual/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/magic_formula_acumulados/ano_igual/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Ativos do ano 2016: ['ALOS3', 'BPAC11', 'BRAV3', 'DIRR3', 'FLRY3', 'HYPE3', 'MGLU3', 'MRVE3', 'MULT3', 'RADL3']
# Carteira do ano 2016 testada para mesmo ano 2015
# Ativos do ano 2017: ['AZZA3', 'BRAP4', 'CPFE3', 'CSMG3', 'ENEV3', 'MGLU3', 'MOVI3', 'PRIO3', 'SLCE3', 'SUZB3']
# Carteira do ano 2017 testada para mesmo ano 2016
# Ativos do ano 2018: ['ALOS3', 'BPAC11', 'ENGI11', 'IRBR3', 'PSSA3', 'RENT3', 'SLCE3', 'SUZB3', 'TEND3', 'VALE3']
# Carteira do ano 2018 testada para mesmo ano 2017
# Ativos do ano 2019: ['BPAC11', 'CPFE3', 'ENEV3', 'IRBR3', 'ISAE4', 'JHSF3', 'PRIO3', 'SAPR11', 'SUZB3', 'TOTS3']
# Carteira do ano 2019 testada para mesmo ano 2018
# Ativos do ano 2020: ['ALOS3', 'CPLE3', 'CXSE3', 'IGTI11', 'RADL3', 'SLCE3', 'SMFT3', 'VBBR3', 'VIVT3', 'WEGE3']
# Carteira do ano 2020 testada para mesmo ano 2019
# Ativos do ano 2021: ['ALOS3', 'BRAV3', 'BRKM5', 'CSNA3', 'EMBJ3', 'ISAE4', 'PRIO3', 'SLCE3', 'SUZB3', 'TAEE11']
# Carteira do ano 2021 testada para mesmo ano 2020
# Ativos do ano 2022: ['ALOS3', 'BBSE3', 'BEEF3', 'BRAP4', 'EGIE3', 'PETR3', 'PETR4', 'SMTO3', 'TAEE11', 'VIVT3']
# Carteira do ano 2022 testada para mesmo ano 2021
# Ativos do ano 2023: ['ALOS3', 'BBSE3', 'BRAP4', 'CSNA3', 'CXSE3', 'EMBJ3', 'POMO4', 'SAPR11', 'VALE3', 'WEGE3']
# Carteira do ano 2023 testada para mesmo ano 2022
# Ativos do ano 2024: ['BBDC4', 'CSMG3', 'CXSE3', 'EMBJ3', 'ITUB3', 'PETR4', 'POMO4', 'SUZB3', 'UGPA3', 'USIM5']
# Carteira do ano 2024 testada para mesmo ano 2023
# Ativos do ano 2025: ['BBSE3', 'BRAV3', 'COGN3', 'CPFE3', 'EMBJ3', 'PETR3', 'PETR4', 'PSSA3', 'SUZB3', 'TOTS3']
# Carteira do ano 2025 testada para mesmo ano 2024
# Ativos do ano 2026: ['ABEV3', 'BRAP4', 'CSMG3', 'PETR3', 'PETR4', 'PRIO3', 'SLCE3', 'USIM5', 'VALE3', 'WEGE3']
# Carteira do ano 2026 testada para mesmo ano 2025

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df[df['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/magic_formula_acumulados/ano_frente/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/magic_formula_acumulados/ano_frente/acumulado_f_ibov/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
