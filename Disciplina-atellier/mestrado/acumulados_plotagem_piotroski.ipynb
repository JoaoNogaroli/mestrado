# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df_carteira = pd.read_csv('carteiras_piotroski.csv').drop(columns=['Unnamed: 0'])

# %%
df_carteira
# Out:
#       ano  ativo    peso
# 0    2016  ANIM3  0.0279
# 1    2016  AXIA3  0.0843
# 2    2016  BRAP4  0.0539
# 3    2016  CSMG3  0.1399
# 4    2016  EQTL3  0.1742
# ..    ...    ...     ...
# 102  2026  RADL3  0.1423
# 103  2026  SLCE3  0.0338
# 104  2026  USIM5  0.0294
# 105  2026  WEGE3  0.1545
# 106  2026  YDUQ3  0.0618
#
# [107 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'

    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/acumulados_piotroski/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Ativos do ano 2016: ['ANIM3', 'AXIA3', 'BRAP4', 'CSMG3', 'EQTL3', 'GGBR4', 'MOVI3', 'MULT3', 'RADL3', 'TOTS3']
# Carteira do ano 2016 testada para mesmo ano 2016
# Ativos do ano 2017: ['ABEV3', 'ANIM3', 'CVCB3', 'EQTL3', 'ITSA4', 'RAIL3', 'SAPR11', 'SUZB3', 'TOTS3', 'WEGE3']
# Carteira do ano 2017 testada para mesmo ano 2017
# Ativos do ano 2018: ['BPAC11', 'BRAV3', 'CPLE3', 'ECOR3', 'ENGI11', 'ITSA4', 'RADL3', 'TOTS3', 'VALE3', 'YDUQ3']
# Carteira do ano 2018 testada para mesmo ano 2018
# Ativos do ano 2019: ['ALOS3', 'CPLE3', 'CYRE3', 'ENGI11', 'ISAE4', 'LREN3', 'MOVI3', 'RAPT4', 'TAEE11', 'YDUQ3']
# Carteira do ano 2019 testada para mesmo ano 2019
# Ativos do ano 2020: ['BPAC11', 'CSNA3', 'CYRE3', 'ENGI11', 'MOVI3', 'RADL3', 'SUZB3', 'TOTS3', 'UGPA3', 'WEGE3']
# Carteira do ano 2020 testada para mesmo ano 2020
# Ativos do ano 2021: ['BEEF3', 'BRAP4', 'CPFE3', 'POMO4', 'PRIO3', 'TEND3', 'UGPA3', 'VALE3']
# Carteira do ano 2021 testada para mesmo ano 2021
# Ativos do ano 2022: ['ALOS3', 'BBAS3', 'BBSE3', 'CSMG3', 'ECOR3', 'ENEV3', 'POMO4', 'PRIO3', 'PSSA3', 'RADL3']
# Carteira do ano 2022 testada para mesmo ano 2022
# Ativos do ano 2023: ['CYRE3', 'ENEV3', 'MOTV3', 'PRIO3', 'PSSA3', 'RADL3', 'RAIL3', 'SMFT3', 'TOTS3', 'VBBR3']
# Carteira do ano 2023 testada para mesmo ano 2023
# Ativos do ano 2024: ['ABEV3', 'BBSE3', 'CPFE3', 'ECOR3', 'ENEV3', 'ITSA4', 'POMO4', 'RAIL3', 'SLCE3', 'SMFT3']
# Carteira do ano 2024 testada para mesmo ano 2024
# Ativos do ano 2025: ['CSMG3', 'CYRE3', 'ENGI11', 'JHSF3', 'LREN3', 'RADL3', 'SLCE3', 'USIM5', 'WEGE3', 'YDUQ3']
# Carteira do ano 2025 testada para mesmo ano 2025
# Ativos do ano 2026: ['CSMG3', 'ENGI11', 'JHSF3', 'LREN3', 'RADL3', 'SLCE3', 'USIM5', 'WEGE3', 'YDUQ3']
# Carteira do ano 2026 testada para mesmo ano 2026

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano+1
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/acumulados_piotroski/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/acumulado_ibov_f/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
