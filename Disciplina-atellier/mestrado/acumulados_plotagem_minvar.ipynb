# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df_carteira = pd.read_csv('carteiras_minvar.csv').drop(columns=['Unnamed: 0'])

# %%
df_carteira
# Out:
#      ano  ativo    peso
# 0   2016  BRKM5  0.0289
# 1   2016  CYRE3  0.0386
# 2   2016  EQTL3  0.1738
# 3   2016  FLRY3  0.1316
# 4   2016  PSSA3  0.0574
# ..   ...    ...     ...
# 95  2026  POMO4  0.0401
# 96  2026  PRIO3  0.0862
# 97  2026  SLCE3  0.1721
# 98  2026  SUZB3  0.0723
# 99  2026  WEGE3  0.0323
#
# [100 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = int(ano)-1
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'

    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/minvar/ano_igual/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/minvar/ano_igual/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Ativos do ano 2016: ['BRKM5', 'CYRE3', 'EQTL3', 'FLRY3', 'PSSA3', 'SLCE3', 'SMTO3', 'SUZB3', 'TAEE11']
# Carteira do ano 2016 testada para mesmo ano 2015
# date
# 2015-04-01    100.349299
# 2015-04-02    100.728276
# 2015-04-06    100.737091
# 2015-04-07    100.716966
# 2015-04-08    100.708312
#                  ...
# 2016-03-24    113.324007
# 2016-03-28    113.866671
# 2016-03-29    114.404458
# 2016-03-30    114.614718
# 2016-03-31    113.212736
# Length: 245, dtype: float64
# Ativos do ano 2017: ['BEEF3', 'BPAC11', 'ENEV3', 'ISAE4', 'MOVI3', 'RAIL3', 'SUZB3', 'TAEE11', 'VIVT3']
# Carteira do ano 2017 testada para mesmo ano 2016
# date
# 2016-04-01     99.895917
# 2016-04-04     99.540425
# 2016-04-05     99.252508
# 2016-04-06     99.111934
# 2016-04-07     98.860993
#                  ...
# 2017-03-27    107.855544
# 2017-03-28    108.630525
# 2017-03-29    108.144134
# 2017-03-30    108.304400
# 2017-03-31    108.369349
# Length: 251, dtype: float64
# Ativos do ano 2018: ['ABEV3', 'BEEF3', 'BPAC11', 'EGIE3', 'ENEV3', 'IRBR3', 'ISAE4', 'SMTO3', 'TOTS3', 'VIVT3']
# Carteira do ano 2018 testada para mesmo ano 2017
# date
# 2017-04-03    100.668026
# 2017-04-04    101.165096
# 2017-04-05    101.423322
# 2017-04-06    100.594863
# 2017-04-07    100.752821
#                  ...
# 2018-03-23    119.496008
# 2018-03-26    120.060335
# 2018-03-27    119.687229
# 2018-03-28    118.862187
# 2018-03-29    119.849700
# Length: 244, dtype: float64
# Ativos do ano 2019: ['CPFE3', 'ENEV3', 'ENGI11', 'HYPE3', 'IRBR3', 'ISAE4', 'PRIO3', 'PSSA3', 'SAPR11', 'SUZB3']
# Carteira do ano 2019 testada para mesmo ano 2018
# date
# 2018-04-02     99.413583
# 2018-04-03     99.583245
# 2018-04-04     99.862799
# 2018-04-05    100.283612
# 2018-04-06    100.576074
#                  ...
# 2019-03-25    140.341057
# 2019-03-26    141.595640
# 2019-03-27    139.213729
# 2019-03-28    140.361246
# 2019-03-29    141.007553
# Length: 245, dtype: float64
# Ativos do ano 2020: ['BBSE3', 'EGIE3', 'ISAE4', 'ITUB3', 'RADL3', 'SUZB3', 'VIVT3']
# Carteira do ano 2020 testada para mesmo ano 2019
# date
# 2019-04-01     99.979780
# 2019-04-02    100.313542
# 2019-04-03    100.445482
# 2019-04-04    101.547740
# 2019-04-05    102.628545
#                  ...
# 2020-03-25    112.914165
# 2020-03-26    114.254306
# 2020-03-27    112.632663
# 2020-03-30    112.122314
# 2020-03-31    111.420323
# Length: 250, dtype: float64
# Ativos do ano 2021: ['AZZA3', 'BRAV3', 'ISAE4', 'KLBN11', 'SAPR11', 'SLCE3', 'SUZB3', 'VALE3']
# Carteira do ano 2021 testada para mesmo ano 2020
# date
# 2020-04-01     98.602921
# 2020-04-02     98.849661
# 2020-04-03     97.232845
# 2020-04-06     99.092109
# 2020-04-07     99.769995
#                  ...
# 2021-03-25    140.141363
# 2021-03-26    141.315861
# 2021-03-29    142.293774
# 2021-03-30    141.950158
# 2021-03-31    141.864388
# Length: 246, dtype: float64
# Ativos do ano 2022: ['ABEV3', 'BBDC4', 'EGIE3', 'ISAE4', 'RADL3', 'SLCE3', 'SUZB3', 'TAEE11', 'VALE3', 'VIVT3']
# Carteira do ano 2022 testada para mesmo ano 2021
# date
# 2021-04-01     99.416453
# 2021-04-05    100.646396
# 2021-04-06    100.719622
# 2021-04-07    100.547049
# 2021-04-08    101.198891
#                  ...
# 2022-03-25    112.408918
# 2022-03-28    112.779583
# 2022-03-29    112.444478
# 2022-03-30    112.822149
# 2022-03-31    112.898484
# Length: 249, dtype: float64
# Ativos do ano 2023: ['ABEV3', 'BRAP4', 'CXSE3', 'EMBJ3', 'ISAE4', 'POMO4', 'SAPR11', 'SLCE3', 'SUZB3', 'TAEE11']
# Carteira do ano 2023 testada para mesmo ano 2022
# date
# 2022-04-01    100.255004
# 2022-04-04    100.109005
# 2022-04-05     98.536263
# 2022-04-06     98.732389
# 2022-04-07     98.212568
#                  ...
# 2023-03-27     98.635049
# 2023-03-28     99.592926
# 2023-03-29    100.251294
# 2023-03-30    100.650986
# 2023-03-31     99.358141
# Length: 251, dtype: float64
# Ativos do ano 2024: ['BBDC4', 'BBSE3', 'CXSE3', 'EMBJ3', 'PETR4', 'SUZB3', 'VALE3', 'VIVT3', 'WEGE3']
# Carteira do ano 2024 testada para mesmo ano 2023
# date
# 2023-04-03    100.008862
# 2023-04-04    100.570281
# 2023-04-05     99.246654
# 2023-04-06     99.935455
# 2023-04-10    101.199200
#                  ...
# 2024-03-22    128.138178
# 2024-03-25    127.412366
# 2024-03-26    127.471468
# 2024-03-27    128.535236
# 2024-03-28    128.493207
# Length: 246, dtype: float64
# Ativos do ano 2025: ['BBSE3', 'CPFE3', 'EGIE3', 'EMBJ3', 'PETR4', 'SAPR11', 'SLCE3', 'SUZB3', 'TAEE11', 'WEGE3']
# Carteira do ano 2025 testada para mesmo ano 2024
# date
# 2024-04-01    100.152239
# 2024-04-02    100.849146
# 2024-04-03    100.778357
# 2024-04-04    100.331830
# 2024-04-05     99.800356
#                  ...
# 2025-03-25    116.184669
# 2025-03-26    116.259292
# 2025-03-27    116.293824
# 2025-03-28    115.631492
# 2025-03-31    114.985797
# Length: 251, dtype: float64
# Ativos do ano 2026: ['ENEV3', 'GGBR4', 'PETR4', 'POMO4', 'PRIO3', 'SLCE3', 'SUZB3', 'WEGE3']
# Carteira do ano 2026 testada para mesmo ano 2025
# date
# 2025-04-01    100.714355
# 2025-04-02    100.356281
# 2025-04-03     98.754724
# 2025-04-04     96.994787
# 2025-04-07     96.485520
#                  ...
# 2026-03-25    118.503389
# 2026-03-26    118.366111
# 2026-03-27    118.900449
# 2026-03-30    119.388646
# 2026-03-31    119.398159
# Length: 250, dtype: float64

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/minvar/ano_frente/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/minvar/ano_frente/acumulado_f_ibov/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
