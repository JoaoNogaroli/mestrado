# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df_carteira = pd.read_csv('carteiras_minvar.csv').drop(columns=['Unnamed: 0'])

# %%
df_carteira
# Out:
#       ano   ativo    peso
# 0    2016   ALOS3  0.1000
# 1    2016  BPAC11  0.0200
# 2    2016   BRAV3  0.2000
# 3    2016   EGIE3  0.0200
# 4    2016  IGTI11  0.0200
# ..    ...     ...     ...
# 100  2026   POMO4  0.0401
# 101  2026   PRIO3  0.0862
# 102  2026   SLCE3  0.1721
# 103  2026   SUZB3  0.0723
# 104  2026   WEGE3  0.0323
#
# [105 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = int(ano)-1
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'

    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/minvar/ano_igual/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/minvar/ano_igual/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Ativos do ano 2016: ['ALOS3', 'BPAC11', 'BRAV3', 'EGIE3', 'IGTI11', 'MDNE3', 'MOVI3', 'SAPR11', 'TEND3', 'VBBR3']
# Carteira do ano 2016 testada para mesmo ano 2015
# date
# 2015-04-01    100.0
# 2015-04-02    100.0
# 2015-04-06    100.0
# 2015-04-07    100.0
# 2015-04-08    100.0
#               ...
# 2016-03-24    100.0
# 2016-03-28    100.0
# 2016-03-29    100.0
# 2016-03-30    100.0
# 2016-03-31    100.0
# Length: 245, dtype: float64
# Ativos do ano 2017: ['ALOS3', 'BRAV3', 'CXSE3', 'IGTI11', 'IRBR3', 'SAPR11', 'SMFT3', 'TEND3', 'VBBR3', 'YDUQ3']
# Carteira do ano 2017 testada para mesmo ano 2016
# date
# 2016-04-01    100.0
# 2016-04-04    100.0
# 2016-04-05    100.0
# 2016-04-06    100.0
# 2016-04-07    100.0
#               ...
# 2017-03-27    100.0
# 2017-03-28    100.0
# 2017-03-29    100.0
# 2017-03-30    100.0
# 2017-03-31    100.0
# Length: 251, dtype: float64
# Ativos do ano 2018: ['ALOS3', 'BRAV3', 'CXSE3', 'IGTI11', 'IRBR3', 'MDNE3', 'SMFT3', 'SMTO3', 'VBBR3', 'YDUQ3']
# Carteira do ano 2018 testada para mesmo ano 2017
# date
# 2017-04-03    100.019681
# 2017-04-04    100.009373
# 2017-04-05    100.094634
# 2017-04-06    100.072511
# 2017-04-07    100.045667
#                  ...
# 2018-03-23    100.980603
# 2018-03-26    100.999722
# 2018-03-27    100.969328
# 2018-03-28    100.941927
# 2018-03-29    100.976626
# Length: 244, dtype: float64
# Ativos do ano 2019: ['ALOS3', 'BRAV3', 'CXSE3', 'ENEV3', 'IGTI11', 'MDNE3', 'SMFT3', 'VBBR3', 'YDUQ3']
# Carteira do ano 2019 testada para mesmo ano 2018
# date
# 2018-04-02    100.050000
# 2018-04-03    100.064789
# 2018-04-04    100.064789
# 2018-04-05    100.075067
# 2018-04-06    100.082372
#                  ...
# 2019-03-25    100.714735
# 2019-03-26    100.742177
# 2019-03-27    100.666350
# 2019-03-28    100.703467
# 2019-03-29    100.733297
# Length: 245, dtype: float64
# Ativos do ano 2020: ['ALOS3', 'BBSE3', 'CXSE3', 'IGTI11', 'ISAE4', 'PSSA3', 'RADL3', 'SMFT3', 'VBBR3']
# Carteira do ano 2020 testada para mesmo ano 2019
# date
# 2019-04-01     99.987473
# 2019-04-02    100.059055
# 2019-04-03    100.143056
# 2019-04-04    100.245096
# 2019-04-05    100.417640
#                  ...
# 2020-03-25    101.574660
# 2020-03-26    101.721560
# 2020-03-27    101.352248
# 2020-03-30    101.267155
# 2020-03-31    101.164918
# Length: 250, dtype: float64
# Ativos do ano 2021: ['ALOS3', 'CXSE3', 'IGTI11', 'SAPR11', 'SMFT3', 'VBBR3', 'VIVT3']
# Carteira do ano 2021 testada para mesmo ano 2020
# date
# 2020-04-01     99.907183
# 2020-04-02     99.837426
# 2020-04-03     99.714497
# 2020-04-06     99.907812
# 2020-04-07    100.037696
#                  ...
# 2021-03-25    100.158565
# 2021-03-26    100.137051
# 2021-03-29    100.130495
# 2021-03-30    100.153353
# 2021-03-31    100.079406
# Length: 246, dtype: float64
# Ativos do ano 2022: ['ABEV3', 'ALOS3', 'EGIE3', 'ISAE4', 'RADL3', 'SLCE3', 'SUZB3', 'TAEE11', 'VALE3', 'VIVT3']
# Carteira do ano 2022 testada para mesmo ano 2021
# date
# 2021-04-01     99.677485
# 2021-04-05    100.640558
# 2021-04-06    100.708954
# 2021-04-07    100.496088
# 2021-04-08    101.075310
#                  ...
# 2022-03-25    110.114888
# 2022-03-28    110.458443
# 2022-03-29    110.102022
# 2022-03-30    110.391050
# 2022-03-31    110.456592
# Length: 249, dtype: float64
# Ativos do ano 2023: ['ABEV3', 'ALOS3', 'BRAP4', 'EMBJ3', 'ISAE4', 'POMO4', 'SAPR11', 'SLCE3', 'SUZB3', 'TAEE11']
# Carteira do ano 2023 testada para mesmo ano 2022
# date
# 2022-04-01    100.268767
# 2022-04-04    100.325808
# 2022-04-05     99.215018
# 2022-04-06     99.379412
# 2022-04-07     98.942184
#                  ...
# 2023-03-27     98.792033
# 2023-03-28     99.539267
# 2023-03-29    100.059394
# 2023-03-30    100.372952
# 2023-03-31     99.300985
# Length: 251, dtype: float64
# Ativos do ano 2024: ['BBDC4', 'BBSE3', 'CXSE3', 'EMBJ3', 'PETR4', 'SUZB3', 'TAEE11', 'VALE3', 'VIVT3', 'WEGE3']
# Carteira do ano 2024 testada para mesmo ano 2023
# date
# 2023-04-03     99.905531
# 2023-04-04    100.771971
# 2023-04-05     99.445690
# 2023-04-06    100.062405
# 2023-04-10    100.699681
#                  ...
# 2024-03-22    130.671713
# 2024-03-25    129.793682
# 2024-03-26    129.926317
# 2024-03-27    131.104670
# 2024-03-28    131.250841
# Length: 246, dtype: float64
# Ativos do ano 2025: ['BBSE3', 'CPFE3', 'EGIE3', 'EMBJ3', 'PETR4', 'SAPR11', 'SLCE3', 'SUZB3', 'TAEE11', 'WEGE3']
# Carteira do ano 2025 testada para mesmo ano 2024
# date
# 2024-04-01    100.152239
# 2024-04-02    100.849146
# 2024-04-03    100.778357
# 2024-04-04    100.331830
# 2024-04-05     99.800356
#                  ...
# 2025-03-25    116.184669
# 2025-03-26    116.259292
# 2025-03-27    116.293824
# 2025-03-28    115.631492
# 2025-03-31    114.985797
# Length: 251, dtype: float64
# Ativos do ano 2026: ['ABEV3', 'BBSE3', 'ENEV3', 'GGBR4', 'PETR4', 'POMO4', 'PRIO3', 'SLCE3', 'SUZB3', 'WEGE3']
# Carteira do ano 2026 testada para mesmo ano 2025
# date
# 2025-04-01    101.324023
# 2025-04-02    100.693929
# 2025-04-03     99.710592
# 2025-04-04     97.276843
# 2025-04-07     95.926983
#                  ...
# 2026-03-25    123.034589
# 2026-03-26    122.462743
# 2026-03-27    122.730280
# 2026-03-30    123.295925
# 2026-03-31    124.353750
# Length: 250, dtype: float64

# %%
# Out:
# date
# 2025-04-01    101.324023
# 2025-04-02    100.693929
# 2025-04-03     99.710592
# 2025-04-04     97.276843
# 2025-04-07     95.926983
#                  ...
# 2026-03-25    123.034589
# 2026-03-26    122.462743
# 2026-03-27    122.730280
# 2026-03-30    123.295925
# 2026-03-31    124.353750
# Length: 250, dtype: float64

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/minvar/ano_frente/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/minvar/ano_frente/acumulado_f_ibov/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
