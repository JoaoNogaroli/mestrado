# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
df_carteira = pd.read_csv('carteiras_linear_sharpe.csv').drop(columns=['Unnamed: 0'])

# %%
df_carteira
# Out:
#       ano  ativo    peso
# 0    2026  ABEV3  0.1624
# 1    2026  BRAP4  0.0200
# 2    2026  CSMG3  0.1887
# 3    2026  PETR4  0.1619
# 4    2026  PRIO3  0.1575
# ..    ...    ...     ...
# 96   2016  HYPE3  0.1742
# 97   2016  MGLU3  0.0357
# 98   2016  MRVE3  0.2000
# 99   2016  SBSP3  0.0692
# 100  2016  SMTO3  0.0891
#
# [101 rows x 3 columns]

# %% [markdown]
# ### ANO IGUAL

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = int(ano)-1
    print(f"Carteira do ano {ano} testada para mesmo ano {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'

    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'
    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/linear_sharpe/ano_igual/acumulado/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/linear_sharpe/ano_igual/acumulado_ibov/ibov_acumulado_{ano_teste}.csv')
        
    except Exception as e:
        pass
# Out:
# ANOS: [2026 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016]
# Ativos do ano 2026: ['ABEV3', 'BRAP4', 'CSMG3', 'PETR4', 'PRIO3', 'SLCE3', 'USIM5', 'VALE3', 'WEGE3']
# Carteira do ano 2026 testada para mesmo ano 2025
# date
# 2025-04-01    100.431593
# 2025-04-02    100.052092
# 2025-04-03     98.482074
# 2025-04-04     95.300785
# 2025-04-07     94.294275
#                  ...
# 2026-03-25    161.758856
# 2026-03-26    161.309940
# 2026-03-27    162.171806
# 2026-03-30    164.121555
# 2026-03-31    164.489653
# Length: 250, dtype: float64
# Ativos do ano 2025: ['BBSE3', 'BRAV3', 'COGN3', 'CPFE3', 'EMBJ3', 'PETR4', 'PSSA3', 'SUZB3']
# Carteira do ano 2025 testada para mesmo ano 2024
# date
# 2024-04-01     99.754234
# 2024-04-02    100.645591
# 2024-04-03    100.742155
# 2024-04-04    100.277775
# 2024-04-05     99.946981
#                  ...
# 2025-03-25    130.462582
# 2025-03-26    131.230276
# 2025-03-27    131.384175
# 2025-03-28    130.757787
# 2025-03-31    130.145542
# Length: 251, dtype: float64
# Ativos do ano 2024: ['CSMG3', 'CXSE3', 'EMBJ3', 'ITUB3', 'PETR4', 'SUZB3', 'UGPA3', 'USIM5']
# Carteira do ano 2024 testada para mesmo ano 2023
# date
# 2023-04-03     99.225764
# 2023-04-04    100.365165
# 2023-04-05     99.002161
# 2023-04-06     99.310974
# 2023-04-10    100.912668
#                  ...
# 2024-03-22    170.727578
# 2024-03-25    170.182286
# 2024-03-26    169.787692
# 2024-03-27    171.679832
# 2024-03-28    171.733159
# Length: 246, dtype: float64
# Ativos do ano 2023: ['BBSE3', 'BRAP4', 'CXSE3', 'EMBJ3', 'KLBN11', 'POMO4', 'SAPR11', 'WEGE3']
# Carteira do ano 2023 testada para mesmo ano 2022
# date
# 2022-04-01    101.278244
# 2022-04-04    101.059523
# 2022-04-05     98.733866
# 2022-04-06     98.798930
# 2022-04-07     98.662776
#                  ...
# 2023-03-27    119.940442
# 2023-03-28    120.980377
# 2023-03-29    121.755051
# 2023-03-30    122.559400
# 2023-03-31    121.008200
# Length: 251, dtype: float64
# Ativos do ano 2022: ['BBAS3', 'BBSE3', 'BEEF3', 'BRAP4', 'EGIE3', 'PETR3', 'PETR4', 'SMTO3', 'TAEE11', 'VIVT3']
# Carteira do ano 2022 testada para mesmo ano 2021
# date
# 2021-04-01     98.641878
# 2021-04-05    100.562100
# 2021-04-06    100.506877
# 2021-04-07    101.324706
# 2021-04-08    101.645806
#                  ...
# 2022-03-25    134.755281
# 2022-03-28    134.671544
# 2022-03-29    133.750252
# 2022-03-30    134.580299
# 2022-03-31    135.706429
# Length: 249, dtype: float64
# Ativos do ano 2021: ['BRAV3', 'BRKM5', 'CSNA3', 'EMBJ3', 'ISAE4', 'PRIO3', 'SLCE3', 'SUZB3', 'TAEE11', 'VALE3']
# Carteira do ano 2021 testada para mesmo ano 2020
# date
# 2020-04-01     97.696157
# 2020-04-02     99.699387
# 2020-04-03     96.702308
# 2020-04-06    100.347823
# 2020-04-07    101.219407
#                  ...
# 2021-03-25    226.782847
# 2021-03-26    230.160680
# 2021-03-29    236.565440
# 2021-03-30    239.555152
# 2021-03-31    239.156170
# Length: 246, dtype: float64
# Ativos do ano 2020: ['CPLE3', 'ENEV3', 'KLBN11', 'MGLU3', 'RADL3', 'SLCE3', 'VIVT3', 'WEGE3']
# Carteira do ano 2020 testada para mesmo ano 2019
# date
# 2019-04-01    100.506048
# 2019-04-02    100.704111
# 2019-04-03     99.832185
# 2019-04-04    101.014293
# 2019-04-05    102.695634
#                  ...
# 2020-03-25    151.032691
# 2020-03-26    158.937753
# 2020-03-27    154.182448
# 2020-03-30    155.186551
# 2020-03-31    155.461217
# Length: 250, dtype: float64
# Ativos do ano 2019: ['BPAC11', 'CPFE3', 'ENEV3', 'IRBR3', 'ISAE4', 'JHSF3', 'PRIO3', 'SAPR11', 'SUZB3', 'TOTS3']
# Carteira do ano 2019 testada para mesmo ano 2018
# date
# 2018-04-02     99.217724
# 2018-04-03     99.753172
# 2018-04-04     99.788093
# 2018-04-05    100.400573
# 2018-04-06    100.352341
#                  ...
# 2019-03-25    158.960981
# 2019-03-26    160.529924
# 2019-03-27    156.713082
# 2019-03-28    158.594319
# 2019-03-29    160.163187
# Length: 245, dtype: float64
# Ativos do ano 2018: ['BPAC11', 'CVCB3', 'ENGI11', 'IRBR3', 'PSSA3', 'RENT3', 'SLCE3', 'SUZB3', 'TEND3', 'VALE3']
# Carteira do ano 2018 testada para mesmo ano 2017
# date
# 2017-04-03    100.330399
# 2017-04-04    101.551119
# 2017-04-05    101.151828
# 2017-04-06    100.213595
# 2017-04-07    100.680436
#                  ...
# 2018-03-23    183.402957
# 2018-03-26    183.769699
# 2018-03-27    182.693364
# 2018-03-28    183.354140
# 2018-03-29    184.566189
# Length: 244, dtype: float64
# Ativos do ano 2017: ['AZZA3', 'BRAP4', 'CPFE3', 'CSMG3', 'ENEV3', 'MGLU3', 'MOVI3', 'PRIO3', 'SLCE3', 'SUZB3']
# Carteira do ano 2017 testada para mesmo ano 2016
# date
# 2016-04-01    102.630194
# 2016-04-04     99.728297
# 2016-04-05     98.785225
# 2016-04-06     97.471446
# 2016-04-07     96.177732
#                  ...
# 2017-03-27    166.993886
# 2017-03-28    168.760998
# 2017-03-29    169.735971
# 2017-03-30    172.715539
# 2017-03-31    174.552211
# Length: 251, dtype: float64
# Ativos do ano 2016: ['BRKM5', 'CSAN3', 'DIRR3', 'ENGI11', 'FLRY3', 'HYPE3', 'MGLU3', 'MRVE3', 'SBSP3', 'SMTO3']
# Carteira do ano 2016 testada para mesmo ano 2015
# date
# 2015-04-01    101.015794
# 2015-04-02    103.372475
# 2015-04-06    105.233847
# 2015-04-07    105.658961
# 2015-04-08    105.896815
#                  ...
# 2016-03-24    149.025810
# 2016-03-28    150.088413
# 2016-03-29    150.990220
# 2016-03-30    151.894753
# 2016-03-31    150.579815
# Length: 245, dtype: float64

# %% [markdown]
# ### ANO PRA FRENTE

# %%
anos = df_carteira.ano.unique()
print(f"ANOS: {anos}")
for ano in anos:
    df_ano = df_carteira[df_carteira['ano']==ano]
    pesos = df_ano.set_index('ativo')['peso']
    # print(df_ano)
    lista_ativos = df_ano.ativo.unique().tolist()
    # print(f"Ativos do ano {ano}: {lista_ativos}")
    # essa lista de ativos é da otimização do ANO X com score do ano x-1
    # Testar essa lista de ativos do ano x para o ano x +1
    ano_teste = ano
    # print(f"Carteira do ano {ano} testada para ano a frente {ano_teste}")
    nome_df = f'retornos_acumulados_plotagem/ativo/df_acumulados_ativos_{ano_teste}.csv'
    
    nome_ibov = f'retornos_acumulados_plotagem/ibov/df_ibov_{ano_teste}.csv'

    try:
        df_retorno = pd.read_csv(nome_df).set_index('date')
        df_retorno = df_retorno[lista_ativos]
        # print(pesos)
        # print(df_retorno)
        carteira_otimizada = (df_retorno*pesos).sum(axis=1)
        carteira_otimizada1 = (carteira_otimizada+1)
        acumulado = carteira_otimizada1.cumprod()*100
        # print(acumulado)
        acumulado.to_csv(f'plotagem_streamlit/linear_sharpe/ano_frente/acumulado_f/acumulado_{ano_teste}.csv')

        df_ibov = pd.read_csv(nome_ibov).set_index('Date')
        df_ibov = df_ibov['IBOV']
        ibov_acumulado = (df_ibov+1).cumprod()*100
        ibov_acumulado.to_csv(f'plotagem_streamlit/linear_sharpe/ano_frente/acumulado_f_ibov/ibov_acumulado_{ano_teste}.csv')
    except Exception as e:
        pass
# Out:
# ANOS: [2026 2025 2024 2023 2022 2021 2020 2019 2018 2017 2016]
