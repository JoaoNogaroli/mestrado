# %%
import pandas as pd
import numpy as np
import random
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.environ import SolverFactory
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ## INICIAR MODELO

# %%
model = pyo.ConcreteModel()

#parametros
capacidade_fabrica = {
    'F1':350,
    'F2':600
}

demanda_cd = {
    'CD1':300,
    'CD2':400,
    'CD3':250
}

#De Para CD1,Cd2,Cd3
custo_transporte = {
    'F1':[8,6,10],
    'F2':[9,12,13]
}

#Definir SET
model.FABRICAS = pyo.Set(initialize=)

# %%
opt = SolverFactory('cplex', executable='C:\\CPLEX_Studio2211\\cplex\\bin\\x64_win64\\cplex.exe')
opt.options['TimeLimit'] = 180 
results = opt.solve(model, tee=True, warmstart=True)
print("-------FIM----------")
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 22.1.1.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2022.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\DECIV\AppData\Local\Temp\tmpn8kni2vm.cplex.log' open.
# CPLEX> New value for time limit in seconds: 180
# CPLEX> Problem 'C:\Users\DECIV\AppData\Local\Temp\tmpsj31qxci.pyomo.lp' read.
# Read time = 0.00 sec. (0.00 ticks)
# CPLEX> MIP start file 'C:\Users\DECIV\AppData\Local\Temp\tmpjm_bdqmd.cplex.mst' read.
# CPLEX> Problem name         : C:\Users\DECIV\AppData\Local\Temp\tmpsj31qxci.pyomo.lp
# Objective sense      : Maximize
# Variables            :       8  [Box: 2,  General Integer: 6]
# Objective nonzeros   :       2
# Linear constraints   :       9  [Less: 7,  Equal: 2]
#   Nonzeros           :      30
#   RHS nonzeros       :       3
#
# Variables            : Min LB: 0.000000         Max UB: 2000.000
# Objective nonzeros   : Min   : 10.00000         Max   : 12.00000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 50.00000
#   RHS nonzeros       : Min   : 2000.000         Max   : 10000.00
# CPLEX> Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_TimeLimit                               180
# 1 of 1 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 0.0000.
# Tried aggregator 1 time.
# MIP Presolve eliminated 9 rows and 8 columns.
# MIP Presolve modified 8 coefficients.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.02 ticks)
# Parallel b&c, 12 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.02 ticks)
#
# Solution pool: 1 solution saved.
#
# MIP - Integer optimal solution:  Objective =  0.0000000000e+00
# Solution time =    0.01 sec.  Iterations = 0  Nodes = 0 (1)
# Deterministic time = 0.02 ticks  (1.38 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\DECIV\AppData\Local\Temp\tmpbwmqwjyi.cplex.sol'.
# CPLEX> -------FIM----------

# %%
for i in model.:
    for r in model.:
        print('----------')
        print('----------')
        print(f"Valor de x{i,r}: ",pyo.value(model.x[i,r]))
        print('------')
# Out:
# ----------
# ----------
# Valor de x('Milho', 'A'):  0.0
# ------
# Producao total de A 0.0
# ----------
# ----------
# Valor de x('Milho', 'B'):  0.0
# ------
# Producao total de B 0.0
# ----------
# ----------
# Valor de x('Soja', 'A'):  0.0
# ------
# Producao total de A 0.0
# ----------
# ----------
# Valor de x('Soja', 'B'):  0.0
# ------
# Producao total de B 0.0
# ----------
# ----------
# Valor de x('Suplemento', 'A'):  0.0
# ------
# Producao total de A 0.0
# ----------
# ----------
# Valor de x('Suplemento', 'B'):  0.0
# ------
# Producao total de B 0.0

# %%
model.pprint()
# Out:
# 2 Set Declarations
#     INGREDIENTES : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'Milho', 'Soja', 'Suplemento'}
#     RACAO : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {'A', 'B'}
#
# 2 Var Declarations
#     producao : Size=2, Index=RACAO
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :   0.0 :  None : False : False : NonNegativeReals
#           B :     0 :   0.0 :  None : False : False : NonNegativeReals
#     x : Size=6, Index=INGREDIENTES*RACAO
#         Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#              ('Milho', 'A') :     0 :   0.0 :  None : False : False : NonNegativeReals
#              ('Milho', 'B') :     0 :   0.0 :  None : False : False : NonNegativeReals
#               ('Soja', 'A') :     0 :   0.0 :  None : False : False : NonNegativeReals
#               ('Soja', 'B') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('Suplemento', 'A') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('Suplemento', 'B') :     0 :   0.0 :  None : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     objetivo : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 10*producao[A] + 12*producao[B]
#
# 4 Constraint Declarations
#     energia : Size=2, Index=RACAO, Active=True
#         Key : Lower : Body                                                              : Upper : Active
#           A :  -Inf : 10*producao[A] - (8*x[Milho,A] + 5*x[Soja,A] + 3*x[Suplemento,A]) :   0.0 :   True
#           B :  -Inf : 15*producao[B] - (8*x[Milho,B] + 5*x[Soja,B] + 3*x[Suplemento,B]) :   0.0 :   True
#     proteina : Size=2, Index=RACAO, Active=True
#         Key : Lower : Body                                                               : Upper : Active
#           A :  -Inf : 20*producao[A] - (5*x[Milho,A] + 10*x[Soja,A] + 2*x[Suplemento,A]) :   0.0 :   True
#           B :  -Inf : 25*producao[B] - (5*x[Milho,B] + 10*x[Soja,B] + 2*x[Suplemento,B]) :   0.0 :   True
#     restricao_disponibilidade : Size=3, Index=INGREDIENTES, Active=True
#         Key        : Lower : Body                              : Upper  : Active
#              Milho :  -Inf :           x[Milho,A] + x[Milho,B] : 1000.0 :   True
#               Soja :  -Inf :             x[Soja,A] + x[Soja,B] :  800.0 :   True
#         Suplemento :  -Inf : x[Suplemento,A] + x[Suplemento,B] :  200.0 :   True
#     restricao_producao : Size=2, Index=RACAO, Active=True
#         Key : Lower : Body                                                   : Upper : Active
#           A :   0.0 : x[Milho,A] + x[Soja,A] + x[Suplemento,A] - producao[A] :   0.0 :   True
#           B :   0.0 : x[Milho,B] + x[Soja,B] + x[Suplemento,B] - producao[B] :   0.0 :   True
#
# 9 Declarations: INGREDIENTES RACAO x producao proteina energia restricao_disponibilidade restricao_producao objetivo
